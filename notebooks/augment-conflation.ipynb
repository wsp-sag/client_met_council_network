# %% [markdown]
# - This notebook is the second step of conflating the old network with the new ranch network
# - It loads the failed links from shst match from step 1
# - It performs nearest match from the old link to the new link
# - First, try to do nearest match using tight tolerance: county, roadway type
# - Then, relax nearest match using county

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import os
import pickle

import ranch

# %%
root_dir = "D:\metcouncil_network_rebuild"

external_dir = os.path.join(root_dir, 'data', 'external')
interim_dir = os.path.join(root_dir, 'data', 'interim')

corrected_network_dir = os.path.join(external_dir, 'rachel_corrected_version')

# %% [markdown]
# ## Links that failed shst match

# %%
# read the file written out from step 1 (roadway-conflation-post-processing.ipynb)

shst_failed_links_gdf = gpd.read_file(os.path.join(interim_dir, "old_model_links_failed_step1_shst_match.geojson"))

# %%
shst_failed_links_gdf.crs
# Out:
# <Projected CRS: EPSG:26915>
# Name: NAD83 / UTM zone 15N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 96°W and 90°W - onshore and offshore. Canada - Manitoba; Nunavut; Ontario. United States (USA) - Arkansas; Illinois; Iowa; Kansas; Louisiana; Michigan; Minnesota; Mississippi; Missouri; Nebraska; Oklahoma; Tennessee; Texas; Wisconsin.
# - bounds: (-96.0, 25.61, -90.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 15N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
shst_failed_links_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 15556 entries, 0 to 15555
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   link_id     15556 non-null  int64
#  1   geoId       13693 non-null  object
#  2   shape_id    15556 non-null  object
#  3   A           15556 non-null  int64
#  4   B           15556 non-null  int64
#  5   distance    15556 non-null  float64
#  6   roadway     15556 non-null  object
#  7   name        14137 non-null  object
#  8   drive       15556 non-null  int64
#  9   walk        15556 non-null  int64
#  10  bike        15556 non-null  int64
#  11  truck       15556 non-null  int64
#  12  centroid    15556 non-null  int64
#  13  mrcc_id     15556 non-null  int64
#  14  ROUTE_SYS   5079 non-null   object
#  15  assgngrp    15556 non-null  int64
#  16  rdclass     15556 non-null  int64
#  17  area_type   15556 non-null  int64
#  18  county      15556 non-null  int64
#  19  mpo         15556 non-null  int64
#  20  AADT        15556 non-null  int64
#  21  count_AM    15556 non-null  int64
#  22  count_MD    15556 non-null  int64
#  23  count_PM    15556 non-null  int64
#  24  count_NT    15556 non-null  int64
#  25  count_day   15556 non-null  int64
#  26  count_year  15556 non-null  int64
#  27  segment_id  15556 non-null  int64
#  28  managed     15556 non-null  int64
#  29  lanes_AM    15556 non-null  int64
#  30  lanes_MD    15556 non-null  int64
#  31  lanes_PM    15556 non-null  int64
#  32  lanes_NT    15556 non-null  int64
#  33  m_lanes_AM  15556 non-null  int64
#  34  m_lanes_MD  15556 non-null  int64
#  35  m_lanes_PM  15556 non-null  int64
#  36  m_lanes_NT  15556 non-null  int64
#  37  access_AM   182 non-null    object
#  38  access_MD   182 non-null    object
#  39  access_PM   182 non-null    object
#  40  access_NT   182 non-null    object
#  41  geometry    15556 non-null  geometry
# dtypes: float64(1), geometry(1), int64(31), object(9)
# memory usage: 5.0+ MB

# %% [markdown]
# ## New Network object from Ranch

# %%
# the polygon file for the area

input_polygon_file = os.path.join(
    external_dir,
    "county", 
    "cb_2018_us_county_500k_withinMETC.geojson"
)

# %%
input_polygon_gdf = gpd.read_file(input_polygon_file)

# %%
input_polygon_gdf
# Out:
#    STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEO
roadway_network = pickle.load(open(working_network_filename, 'rb'))

# %%
# number of unique shstReferenceIds in the network
print(roadway_network.links_df.shstReferenceId.nunique())

# number of unique shstGeometryIds in the network
print(roadway_network.links_df.shstGeometryId.nunique())
# Out:
# 1061566
# 556550

# %%
roadway_network.links_df.columns
# Out:
# Index(['shstReferenceId', 'id', 'shstGeometryId', 'fromIntersectionId',
#        'toIntersectionId', 'geometry', 'u', 'v', 'nodeIds', 'wayId',
#        'roadClass', 'oneWay', 'roundabout', 'link', 'oneway', 'lanes', 'ref',
#        'name', 'highway', 'service', 'width', 'maxspeed', 'access', 'junction',
#        'bridge', 'tunnel', 'landuse', 'area', 'key', 'forward',
#        'backReferenceId', 'metadata', 'source', 'roadway', 'drive_access',
#        'walk_access', 'bike_access', 'county', 'length', 'A', 'B',
#        'model_link_id', 'locationReferences', 'rail_only'],
#       dtype='object')

# %%
roadway_network.links_df['county'].value_counts()
# Out:
# Hennepin      284405
# Ramsey        159952
# Dakota        109928
# Washington     89742
# Anoka          81587
# Wright         42468
# Carver         42238
# Scott          32515
# St. Croix      32325
# Isanti         26320
# McLeod         25333
# Goodhue        25215
# Rice           22781
# Polk           22290
# Sherburne      17415
# Chisago        14965
# Pierce         12440
# Le Sueur       10091
# Sibley          9556
# Name: county, dtype: int64

# %% [markdown]
# ## Unmatched links by county

# %%
input_polygon_gdf = input_polygon_gdf.to_crs(shst_failed_links_gdf.crs)

# %%
# add county name to the unmatched links

shst_failed_links_gdf = gpd.sjoin(
    shst_failed_links_gdf,
    input_polygon_gdf[['NAME','geometry']],
    how = 'left',
    predicate = 'intersects'
)

# %%
shst_failed_links_gdf['NAME'].unique()
# Out:
# array(['Carver', 'Dakota', 'Goodhue', nan, 'Polk', 'Wright', 'Washington',
#        'Rice', 'Scott', 'Hennepin', 'Sherburne', 'Anoka', 'Isanti',
#        'St. Croix', 'Ramsey', 'Chisago', 'Sibley', 'McLeod', 'Le Sueur',
#        'Pierce'], dtype=object)

# %%
shst_failed_links_gdf[['A','B','link_id', 'geometry','NAME','geoId', 'roadway']]
# Out:
#             A       B  link_id  \
# 0        3181  136718      126
# 1        3208    3218      179
# 2        3208    3213      180
# 3        3208    3238      181
# 4        3213    3238      191
# ...       ...     ...      ...
# 15551  170173   81044   420982
# 15552  170533  155559   421056
# 15553  170689    3182   421084
# 15554  170938   30575   421141
# 15555  351036  117460  1095601
#
#                                                 geometry      NAME  \
# 0      LINESTRING (457432.560 4966007.165, 457432.963...    Carver
# 1      LINESTRING (486780.485 4944095.268, 486780.881...    Dakota
# 2      LINESTRING (486780.485 4944095.268, 486783.315...    Dakota
# 3      LINESTRING (486780.485 4944095.268, 486771.304...    Dakota
# 4      LINESTRING (486772.989 4944295.285, 486762.738...    Dakota
# ...                                                  ...       ...
# 15551  LINESTRING (440044.295 5015376.045, 440076.158...    Wright
# 15552  LINESTRING (478579.400 4967651.199, 478502.625...  Hennepin
# 15553  LINESTRING (442026.980 5014003.096, 441666.718...    Wright
# 15554  LINESTRING (482867.200 4967694.028, 482775.853...  Hennepin
# 15555  LINESTRING (478145.246 4979773.254, 478256.946...  Hennepin
#
#                                   geoId      roadway
# 0                                  None     tertiary
# 1      cbd9b2da3888ca5ed49bf24379602b22  residential
# 2      f20f27b848b5de5e335aaa1a3f22988a  residential
# 3      822ed14e4356e4e46886b9dd4ed828ca  residential
# 4      aa4faa2a8bc878ed5b3522ce216588a5  residential
# ...                                 ...          ...
# 15551  342c3320b613ee978c9d2fa7b01f0dff     motorway
# 15552  c955d90085855c3b78fa16a8bebf70a2     motorway
# 15553  4d0815a7cb52ded0dfed8d750b56c067     motorway
# 15554  1bf79b100ad1fd5ae7003e43f693e9ab     motorway
# 15555                              None  residential
#
# [15832 rows x 7 columns]

# %%
shst_failed_links_gdf.roadway.unique()
# Out:
# array(['tertiary', 'residential', 'road', 'planned', 'rest', 'secondary',
#        'motorway', 'primary', 'trunk', 'unclassified'], dtype=object)

# %%
roadway_network.shapes_df.roadClass.value_counts()
# Out:
# Residential     213862
# Other           139931
# Service          95014
# Tertiary         68621
# Secondary        18801
# Primary           7277
# Motorway          5820
# Unclassified      3965
# Trunk             3259
# Name: roadClass, dtype: int64

# %% [markdown]
# ## Match using nearest link

# %%
roadway_network.shapes_df.columns
# Out:
# Index(['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId',
#        'backReferenceId', 'roadClass', 'metadata', 'geometry', 'source'],
#       dtype='object')

# %%
ranch_shape_gdf = pd.merge(
    roadway_network.shapes_df[['id','roadClass','geometry']].rename(columns = {'id':'shstGeometryId'}),
    roadway_network.links_df[['shstGeometryId','county']].drop_duplicates(),
    how = 'left',
    on = 'shstGeometryId'
)

# %%
ranch_shape_gdf
# Out:
#                           shstGeometryId    roadClass  \
# 0       72bf2bff013aa4e226045ec58c9d7b6c        Other
# 1       142f13a0c93978786b6021b934499302      Service
# 2       3c484f858736b95176b99b2add8bf128  Residential
# 3       5e885f48739a926e1feac24992e4cd9b  Residential
# 4       d64c53ac46a122059ae55f3453087ac4      Service
# ...                                  ...          ...
# 556545  959dc9ae8b104ed11c2fddbc6e1b37a7  Residential
# 556546  e99d23aed94ca66e52c63d8bbd727bc4  Residential
# 556547  8a4e0f59a0e8ebd97d67740d27913e08  Residential
# 556548  6e208aed19d84f18ce2c09af6e31d6bc  Residential
# 556549  4a62aa4e91d64078a4b180493747d326  Residential
#
#                                                  geometry  county
# 0       LINESTRING (-93.18911 44.93969, -93.18958 44.9...  Ramsey
# 1       LINESTRING (-93.18808 44.93956, -93.18958 44.9...  Ramsey
# 2       LINESTRING (-93.18806 44.93703, -93.18993 44.9...  Ramsey
# 3       LINESTRING (-93.18993 44.93747, -93.18993 44.9...  Ramsey
# 4       LINESTRING (-93.18806 44.93747, -93.18993 44.9...  Ramsey
# ...                                                   ...     ...
# 556545  LINESTRING (-92.72710 44.71595, -92.72774 44.7...  Pierce
# 556546  LINESTRING (-92.72421 44.71995, -92.72413 44.7...  Pierce
# 556547  LINESTRING (-92.73143 44.74704, -92.72857 44.7...  Pierce
# 556548  LINESTRING (-92.73143 44.74704, -92.73142 44.7...  Pierce
# 556549  LINESTRING (-92.71098 44.71435, -92.71082 44.7...  Pierce
#
# [556550 rows x 4 columns]

# %%
# convert crs to meter based

ranch_shape_gdf = ranch_shape_gdf.to_crs(shst_failed_links_gdf.crs)

# %% [markdown]
# #### first use tight tolerance

# %%
# match based on pems route, direction, and tomtom shieldnum, rtedir
# match based on facility type, county

offset = 20

tight_match_gdf = gpd.GeoDataFrame()

for county in shst_failed_links_gdf.NAME.unique():
    unmatched_subset_gdf = shst_failed_links_gdf[shst_failed_links_gdf.NAME == county].copy()
    
    for roadway in unmatched_subset_gdf.roadway.unique():
        
        print("county {}, roadway {}".format(county, roadway))
        
        subset_gdf = unmatched_subset_gdf[(unmatched_subset_gdf.roadway == roadway)].copy()
        subset_gdf['geometry'] = subset_gdf['geometry'].representative_point()
        
        bbox = subset_gdf.bounds + [-offset, -offset, offset, offset]
    
        shape = ranch_shape_gdf[
            (ranch_shape_gdf.roadClass.str.contains(roadway,case=False)) & 
            (ranch_shape_gdf.county == county)
        ].copy()

        if len(shape) == 0:
            shape = ranch_shape_gdf[
                (ranch_shape_gdf.county == county)
            ].copy()
        
        if len(shape) == 0:
            print("\t ranch does not county {}, roadway {}".format(county, roadway))
            continue
        
        hits = bbox.apply(lambda row: list(shape.sindex.intersection(row)),
                  axis = 1)
        
        tmp = pd.DataFrame({
            # index of points table
            "pt_idx": np.repeat(hits.index, hits.apply(len)),
            # ordinal position of line - access via iloc later
            "shape_i": np.concatenate(hits.values)
        })
        
        # join with pems
        
        tmp.set_index(["pt_idx"], inplace = True)
        
        tmp = tmp.join(subset_gdf.rename(
                                columns = {"geometry" : "point"}), 
                       how = "left")
        
        # join with links
        
        tmp.set_index(["shape_i"], inplace = True)
        
        tmp = tmp.join(shape.drop(columns =['county']).reset_index(drop=True), 
                       how="left")
        
        # find closest line to point
        
        tmp = gpd.GeoDataFrame(tmp, geometry = tmp["geometry"], crs = subset_gdf.crs)
        
        tmp["snap_distance"]  = tmp.geometry.distance(gpd.GeoSeries(tmp.point))
        
        tmp.sort_values(by = ["snap_distance"], inplace = True)
        
        closest = tmp.groupby(["link_id"]).first().reset_index()
        
        tight_match_gdf = pd.concat([tight_match_gdf, closest],
                                   sort = False,
                                   ignore_index = True)
# Out:
# county Carver, roadway tertiary
# county Carver, roadway residential
# county Carver, roadway secondary
# county Carver, roadway primary
# county Carver, roadway motorway
# county Carver, roadway unclassified
# county Carver, roadway trunk
# county Dakota, roadway residential
# county Dakota, roadway road
# county Dakota, roadway tertiary
# county Dakota, roadway secondary
# county Dakota, roadway trunk
# county Dakota, roadway motorway
# county Dakota, roadway unclassified
# county Dakota, roadway primary
# county Goodhue, roadway residential
# county Goodhue, roadway tertiary
# county Goodhue, roadway primary
# county Goodhue, roadway trunk
# county Goodhue, roadway secondary
# county Goodhue, roadway unclassified
# county Polk, roadway residential
# county Polk, roadway tertiary
#                                point index_right      NAME  \
# 7045  POINT (468766.296 4967284.047)         0.0  Hennepin
#
#                         shstGeometryId  roadClass  \
# 7045  0664e8becfb36ee9afb2ebea3918e32d   Motorway
#
#                                                geometry  snap_distance
# 7045  LINESTRING (468827.678 4967352.156, 468826.068...       7.910785
#
# [1 rows x 48 columns]

# %% [markdown]
# #### then use relaxed match for failed ones

# %%
# match based on pems route, direction, and tomtom shieldnum, rtedir
# match based on facility type, county

offset = 20

relaxed_match_gdf = gpd.GeoDataFrame()

reduced_shst_failed_links_gdf = shst_failed_links_gdf[~shst_failed_links_gdf.link_id.isin(tight_match_gdf.link_id)]

for county in reduced_shst_failed_links_gdf.NAME.unique():
    unmatched_subset_gdf = reduced_shst_failed_links_gdf[reduced_shst_failed_links_gdf.NAME == county].copy()
    
    for roadway in unmatched_subset_gdf.roadway.unique():
        
        print("county {}, roadway {}".format(county, roadway))
        
        subset_gdf = unmatched_subset_gdf[(unmatched_subset_gdf.roadway == roadway)].copy()
        subset_gdf['geometry'] = subset_gdf['geometry'].representative_point()
        
        bbox = subset_gdf.bounds + [-offset, -offset, offset, offset]
    
        shape = ranch_shape_gdf[
            #(ranch_shape_gdf.roadClass.str.contains(roadway,case=False)) & 
            (ranch_shape_gdf.county == county)
        ].copy()

        if len(shape) == 0:
            shape = ranch_shape_gdf[
                (ranch_shape_gdf.county == county)
            ].copy()
        
        if len(shape) == 0:
            print("\t ranch does not county {}, roadway {}".format(county, roadway))
            continue
        
        hits = bbox.apply(lambda row: list(shape.sindex.intersection(row)),
                  axis = 1)
        
        tmp = pd.DataFrame({
            # index of points table
            "pt_idx": np.repeat(hits.index, hits.apply(len)),
            # ordinal position of line - access via iloc later
            "shape_i": np.concatenate(hits.values)
        })
        
        # join with pems
        
        tmp.set_index(["pt_idx"], inplace = True)
        
        tmp = tmp.join(subset_gdf.rename(
                                columns = {"geometry" : "point"}), 
                       how = "left")
        
        # join with links
        
        tmp.set_index(["shape_i"], inplace = True)
        
        tmp = tmp.join(shape.drop(columns =['county']).reset_index(drop=True), 
                       how="left")
        
        # find closest line to point
        
        tmp = gpd.GeoDataFrame(tmp, geometry = tmp["geometry"], crs = subset_gdf.crs)
        
        tmp["snap_distance"]  = tmp.geometry.distance(gpd.GeoSeries(tmp.point))
        
        tmp.sort_values(by = ["snap_distance"], inplace = True)
        
        closest = tmp.groupby(["link_id"]).first().reset_index()
        
        relaxed_match_gdf = pd.concat([relaxed_match_gdf, closest],
                                   sort = False,
                                   ignore_index = True)
# Out:
# county Carver, roadway tertiary
# county Carver, roadway residential
# county Carver, roadway unclassified
# county Goodhue, roadway residential
# county Goodhue, roadway tertiary
# county Goodhue, roadway trunk
# county Goodhue, roadway unclassified
# county Goodhue, roadway secondary
# county Polk, roadway residential
# county Polk, roadway secondary
# county Polk, roadway unclassified
# county Wright, roadway residential
# county Wright, roadway tertiary
# county Wright, roadway secondary
# county Wright, roadway primary
# county Rice, roadway tertiary
# county Rice, roadway residential
# county Rice, roadway secondary
# ..                         ...    ...   ...  ...        ...        ...
# 664               530th Avenue      1     1  ...       None       None
# 665               530th Avenue      1     1  ...       None       None
# 666  190th Street,130th Avenue      1     1  ...       None       None
# 667               301st Avenue      1     1  ...       None       None
# 668               301st Avenue      1     1  ...       None       None
#
#      access_NT                           point index_right    NAME  \
# 0         None  POINT (457472.450 4966185.588)         7.0  Carver
# 1         None  POINT (434855.772 4964522.992)         7.0  Carver
# 2         None  POINT (434848.964 4964564.199)         7.0  Carver
# 3         None  POINT (434861.561 4964755.556)         7.0  Carver
# 4         None  POINT (434857.607 4964734.377)         7.0  Carver
# ..         ...                             ...         ...     ...
# 664       None  POINT (535208.911 4953263.746)         9.0  Pierce
# 665       None  POINT (535208.911 4953263.746)         9.0  Pierce
# 666       None  POINT (561783.112 4936943.011)         9.0  Pierce
# 667       None  POINT (529622.991 4944123.686)         9.0  Pierce
# 668       None  POINT (529622.991 4944123.686)         9.0  Pierce
#
#                        shstGeometryId    roadClass  \
# 0    46a97c1d3dcff493d6f3294ee93a1024        Other
# 1    de68f20ad9550b8b30f491cc56366994  Residential
# 2    de68f20ad9550b8b30f491cc56366994  Residential
# 3    02275e3b2bf790d9495ad0b8be12db3c  Residential
# 4    de68f20ad9550b8b30f491cc56366994  Residential
# ..                                ...          ...
# 664  fe02808a07e6979b7c2434500b4a5182      Primary
# 665  fe02808a07e6979b7c2434500b4a5182      Primary
# 666  08ac5c90c02ba66c0f3eaef4c0c0d067        Other
# 667  3ad9693fa97df6652ac0d80d900c1b13      Primary
# 668  3ad9693fa97df6652ac0d80d900c1b13      Primary
#
#                                               geometry  snap_distance
# 0    LINESTRING (457432.560 4966007.165, 457432.963...   1.408613e-09
# 1    LINESTRING (434870.201 4964755.502, 434868.357...   3.506193e+00
# 2    LINESTRING (434870.201 4964755.502, 434868.357...   1.234421e+01
# 3    LINESTRING (434492.906 4964757.450, 434601.117...   2.713648e-02
# 4    LINESTRING (434870.201 4964755.502, 434868.357...   1.179554e+01
# ..                                                 ...            ...
# 664  LINESTRING (535086.745 4953173.767, 535270.941...   4.048765e+01
# 665  LINESTRING (535086.745 4953173.767, 535270.941...   4.048765e+01
# 666  LINESTRING (562229.625 4936950.061, 562110.159...   1.862157e-09
# 667  LINESTRING (529708.741 4944030.547, 529631.816...   4.802174e+01
# 668  LINESTRING (529708.741 4944030.547, 529631.816...   4.802174e+01
#
# [669 rows x 48 columns]

# %% [markdown]
# ## organize match outcome

# %%
# combine tight and relaxed match outcome
match_gdf = pd.concat(
    [tight_match_gdf, relaxed_match_gdf],
    sort = False,
    ignore_index = True
)

# %%
out_match_gdf = pd.merge(
    match_gdf[['link_id','A','B','NAME','geoId','roadway','geometry','snap_distance','shstGeometryId']].rename(
        columns = {'link_id':'model_link_id_old', 'NAME':'county', 'A':'A_old','B':'B_old'}
    ),
    roadway_network.links_df[['model_link_id','A','B','shstGeometryId', 'shstReferenceId']].rename(
        columns = {'model_link_id':'model_link_id_new', 'A':'A_new','B':'B_new'}
    ),
    how = 'left',
    on = "shstGeometryId"
)

# %%
out_match_gdf.model_link_id_old.nunique()
# Out:
# 13466

# %%
out_match_gdf
# Out:
#        model_link_id_old   A_old   B_old  county  \
# 0                 190365   87088  131048  Carver
# 1                 190365   87088  131048  Carver
# 2                 222373  100245  136963  Carver
# 3                 222373  100245  136963  Carver
# 4                 224395  101068  101072  Carver
# ...                  ...     ...     ...     ...
# 26134             218806   98848   73443  Pierce
# 26135             269962  120833  120876  Pierce
# 26136             269962  120833  120876  Pierce
# 26137             270058  120876  120833  Pierce
# 26138             270058  120876  120833  Pierce
#
#                                   geoId      roadway  \
# 0      5d71e5bdddb801d7808004bcebfa3530     tertiary
# 1      5d71e5bdddb801d7808004bcebfa3530     tertiary
# 2                                  None     tertiary
# 3                                  None     tertiary
# 4      9cdeaa2f98802337f6820fca84fe13cc     tertiary
# ...                                 ...          ...
# 26134                              None  residential
# 26135  5acda57a8d502486216468ad53e9b8ec  residential
# 26136  5acda57a8d502486216468ad53e9b8ec  residential
# 26137  5acda57a8d502486216468ad53e9b8ec  residential
# 26138  5acda57a8d502486216468ad53e9b8ec  residential
#
#                                                 geometry  snap_distance  \
# 0      LINESTRING (420558.656 4980247.723, 420579.704...   9.129683e-10
# 1      LINESTRING (420558.656 4980247.723, 420579.704...   9.129683e-10
# 2      LINESTRING (422572.941 4980999.285, 422571.916...   0.000000e+00
# 3      LINESTRING (422572.941 4980999.285, 422571.916...   0.000000e+00
# 4      LINESTRING (427836.843 4976901.053, 427092.451...   0.000000e+00
# ...                                                  ...            ...
# 26134  LINESTRING (562229.625 4936950.061, 562110.159...   1.862157e-09
# 26135  LINESTRING (529708.741 4944030.547, 529631.816...   4.802174e+01
# 26136  LINESTRING (529708.741 4944030.547, 529631.816...   4.802174e+01
# 26137  LINESTRING (529708.741 4944030.547, 529631.816...   4.802174e+01
# 26138  LINESTRING (529708.741 4944030.547, 529631.816...   4.802174e+01
#
#                          shstGeometryId  model_link_id_new   A_new   B_new  \
# 0      037de3fe8189159ca2b94a98eb539d98               6439   63305   65512
# 1      037de3fe8189159ca2b94a98eb539d98             608375   65512   63305
# 2      f8d56ca3cb68a17f30ddd8283c3cd4a4             229391   65398   69104
# 3      f8d56ca3cb68a17f30ddd8283c3cd4a4            1017691   69104   65398
# 4      d32278c27cfe8dc8ca33db1695d4a5f2             374013   61156   61157
# ...                                 ...                ...     ...     ...
# 26134  08ac5c90c02ba66c0f3eaef4c0c0d067             629219  187467  183713
# 26135  3ad9693fa97df6652ac0d80d900c1b13              39318  189346  189354
# 26136  3ad9693fa97df6652ac0d80d900c1b13             900646  189354  189346
# 26137  3ad9693fa97df6652ac0d80d900c1b13              39318  189346  189354
# 26138  3ad9693fa97df6652ac0d80d900c1b13             900646  189354  189346
#
#                         shstReferenceId
# 0      02fc891611aaac18aef3652640908e71
# 1      1bdf5e679736f0a422530f4f57c18daa
# 2      69e433096409bdda0b4b0ba6a44ed952
# 3      ec3756c4b75867a8560c277fe3779ff6
# 4      acff5fd53c379cbfa5081bde220abd8a
# ...                                 ...
# 26134  2666874e6a25e7997678a9d350637cf1
# 26135  1205275ab78ade71d950127d499acd10
# 26136  b056de4bda72c0d7670ad8ed2d1cd26d
# 26137  1205275ab78ade71d950127d499acd10
# 26138  b056de4bda72c0d7670ad8ed2d1cd26d
#
# [26139 rows x 13 columns]

# %% [markdown]
# #### write out matched links using step 2

# %%
out_match_gdf.to_file(os.path.join(interim_dir, "step2_matched.geojson"), driver = "GeoJSON")

# %% [markdown]
# #### write out unmatched links after step 2

# %%
shst_failed_links_gdf[~(shst_failed_links_gdf.link_id.isin(out_match_gdf["model_link_id_old"].unique()))].to_file(
    os.path.join(interim_dir, 'old_model_links_failed_step2_nearest_match.geojson'), driver = "GeoJSON"
)

# %%
shst_failed_links_gdf[~(shst_failed_links_gdf.link_id.isin(out_match_gdf["model_link_id_old"].unique()))].shape
# Out:
# (2104, 44)

# %% [markdown]
# ## add to the crosswalk

# %%
# exisiting crosswalk
crosswalk_df = pd.read_csv(os.path.join(interim_dir, 'model_network_id_crosswalk_step1_from_shst.csv'))

# %%
crosswalk_df
# Out:
#                          shstReferenceId   A_old   B_old  model_link_id_old  \
# 0       c2f57cd96062b9cc5696feed9739f4b7    3153   10010                 82
# 1       e9162d6a8e1d33d5a7a5cbdce7f23266    3153    3859                 83
# 2       d592a065763a320947a181cb28f603ea    3153  165440                 84
# 3       0c93d7c2521821337f48297b7f243a5e    3153  165440                 84
# 4       c75d2fc0c7de11abc01d9deb763f720e    3165  118345                102
# ...                                  ...     ...     ...                ...
# 463658  1b60035f47c097aeefea115da7eda642  170183  170181             420988
# 463659  ece3f1efb5b15b12d3c5392554a85ea1  170183   74513             420989
# 463660  9ef969963ce79d46547a562b5b5165ad  170184   77840             420990
# 463661  144014db4526a260bd4e116e0c5394c6  171166   58874             421172
# 463662  6d198b98b01795f43475c51095538749  171166   58869             421173
#
#                           shstGeometryId  model_link_id_new     A_new  \
# 0       4182fb024a75046c971ec6b44529a336           937127.0  200714.0
# 1       5ed091cb952ad1a07b0cc96d85242ece           504352.0  200714.0
# 2       710762f57a26720c4076aec65a3953ae           462155.0  200714.0
# 3       aac137ff123bd4b1467ea3a532120764            27498.0  289953.0
# 4       b5e7ddb3e598d4966700af7a3721c72c           431150.0  259650.0
# ...                                  ...                ...       ...
# 463658  2a24b9bb9a9659bcc8c4cf2d27a6f53a            59543.0  257090.0
# 463659  4014d1bb3d7d527efdc99f266addf245           512486.0  257090.0
# 463660  cbf18ef01ebfb998c121cd711d5917da           343666.0  257089.0
# 463661  a1d78cf6cb5d4ebedb0083a2f894e864            44128.0  361327.0
# 463662  f80dcf1b223f479b069917e71a8e9ae1           768279.0  361327.0
#
#            B_new
# 0        36302.0
# 1       200718.0
# 2       289953.0
# 3        34433.0
# 4        10191.0
# ...          ...
# 463658  257088.0
# 463659  183970.0
# 463660  339119.0
# 463661  181049.0
# 463662  181048.0
#
# [463663 rows x 8 columns]

# %%
augmented_crosswalk_df = pd.concat(
    [
        crosswalk_df,
        out_match_gdf[[c for c in out_match_gdf.columns if c in crosswalk_df.columns]]
    ],
    sort = False,
    ignore_index = True
)

# %%
augmented_crosswalk_df['model_link_id_new'] = augmented_crosswalk_df['model_link_id_new'].astype(int)
augmented_crosswalk_df['A_new'] = augmented_crosswalk_df['A_new'].astype(int)
augmented_crosswalk_df['B_new'] = augmented_crosswalk_df['B_new'].astype(int)
augmented_crosswalk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489802 entries, 0 to 489801
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   shstReferenceId    489802 non-null  object
#  1   A_old              489802 non-null  int64
#  2   B_old              489802 non-null  int64
#  3   model_link_id_old  489802 non-null  int64
#  4   shstGeometryId     489802 non-null  object
#  5   model_link_id_new  489802 non-null  int32
#  6   A_new              489802 non-null  int32
#  7   B_new              489802 non-null  int32
# dtypes: int32(3), int64(3), object(2)
# memory usage: 24.3+ MB

# %%
augmented_crosswalk_df
# Out:
#                          shstReferenceId   A_old   B_old  model_link_id_old  \
# 0       c2f57cd96062b9cc5696feed9739f4b7    3153   10010                 82
# 1       e9162d6a8e1d33d5a7a5cbdce7f23266    3153    3859                 83
# 2       d592a065763a320947a181cb28f603ea    3153  165440                 84
# 3       0c93d7c2521821337f48297b7f243a5e    3153  165440                 84
# 4       c75d2fc0c7de11abc01d9deb763f720e    3165  118345                102
# ...                                  ...     ...     ...                ...
# 489797  2666874e6a25e7997678a9d350637cf1   98848   73443             218806
# 489798  1205275ab78ade71d950127d499acd10  120833  120876             269962
# 489799  b056de4bda72c0d7670ad8ed2d1cd26d  120833  120876             269962
# 489800  1205275ab78ade71d950127d499acd10  120876  120833             270058
# 489801  b056de4bda72c0d7670ad8ed2d1cd26d  120876  120833             270058
#
#                           shstGeometryId  model_link_id_new   A_new   B_new
# 0       4182fb024a75046c971ec6b44529a336             937127  200714   36302
# 1       5ed091cb952ad1a07b0cc96d85242ece             504352  200714  200718
# 2       710762f57a26720c4076aec65a3953ae             462155  200714  289953
# 3       aac137ff123bd4b1467ea3a532120764              27498  289953   34433
# 4       b5e7ddb3e598d4966700af7a3721c72c             431150  259650   10191
# ...                                  ...                ...     ...     ...
# 489797  08ac5c90c02ba66c0f3eaef4c0c0d067             629219  187467  183713
# 489798  3ad9693fa97df6652ac0d80d900c1b13              39318  189346  189354
# 489799  3ad9693fa97df6652ac0d80d900c1b13             900646  189354  189346
# 489800  3ad9693fa97df6652ac0d80d900c1b13              39318  189346  189354
# 489801  3ad9693fa97df6652ac0d80d900c1b13             900646  189354  189346
#
# [489802 rows x 8 columns]

# %%
# new crosswalk
augmented_crosswalk_df.to_csv(os.path.join(interim_dir, 'model_network_id_crosswalk_step2_augmented.csv'),index=False)

# %%
augmented_crosswalk_df[augmented_crosswalk_df.model_link_id_old == 383240]
# Out:
#                          shstReferenceId  A_old  B_old  model_link_id_old  \
# 477422  97e7aa2b0b940c791f3cdcf0011abb27  10916   3800             383240
#
#                           shstGeometryId  model_link_id_new   A_new   B_new
# 477422  0664e8becfb36ee9afb2ebea3918e32d             328353  369952  201278
