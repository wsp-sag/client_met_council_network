# %% [markdown]
# # Ranch Demo Notebook
#
# This notebook has examples of how to make Ranch calls to run through the complete network building pipeline to develop standard roadway and transit network from scratch

# %%
import os
import pickle
import pandas as pd
import geopandas as gpd
from pyproj import CRS
import json
import sys
import numpy as np

import ranch
from ranch import sharedstreets
from ranch import Roadway
from ranch import Transit
from ranch import Parameters
from ranch.utils import link_df_to_geojson, point_df_to_geojson
from ranch.logger import RanchLogger

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Remote I/O
#
# User to update, project directory is not necessarily the ranch directory

# %%
# project directory
root_dir = os.path.join("D:/metcouncil_network_rebuild")

external_dir = os.path.join(root_dir, "data", "external")
interim_dir = os.path.join(root_dir, "data", "interim")

# software directory
ranch_dir = os.path.join("D:/github/Ranch")

# the folder where SharedStreets extractions live

shst_extract_dir = os.path.join(external_dir, "sharedstreets_extract")

# the folder where OSMNX extractions live

osm_extract_dir = os.path.join(external_dir, "osmnx_extract")

# %%
parameters = Parameters(ranch_base_dir = ranch_dir)
# Out:
# 2022-03-07 12:22:16, INFO: Lasso base directory set as: D:/github/Ranch

# %%
parameters.standard_crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
for d in [root_dir, external_dir, interim_dir, shst_extract_dir, osm_extract_dir]:
    if os.path.isdir(d):
        print(f"{d} exists!")
        continue
    
    print(f"creating {d}")
    os.makedirs(d)
# Out:
# D:/metcouncil_network_rebuild exists!
# D:/metcouncil_network_rebuild\data\external exists!
# D:/metcouncil_network_rebuild\data\interim exists!
# D:/metcouncil_network_rebuild\data\external\sharedstreets_extract exists!
# D:/metcouncil_network_rebuild\data\external\osmnx_extract exists!

# %% [markdown]
# ## Step 1 - SharedStreets Extraction
#
# Extracts sharedstreets representation of OSM links.
# The input for this step is the polygon boundary file for the area.
# The output for this step is geojson files from SharedStreets API.

# %%
# the polygon file for the area

input_polygon_file = os.path.join(
    external_dir,
    "county", 
    "cb_2018_us_county_500k_withinMETC.geojson"
)

# %%
# the SharedStreets extraction file is saved to the 'output_dir' argument

ranch.run_shst_extraction(
    input_polygon_file = input_polygon_file,
    output_dir = shst_extract_dir
)
# Out:
# 2022-03-06 17:01:31, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.0.geojson
# 2022-03-06 17:01:31, INFO: extracting for polygon 0
# 2022-03-06 17:02:56, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.1.geojson
# 2022-03-06 17:02:56, INFO: extracting for polygon 1
# 2022-03-06 17:03:38, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.2.geojson
# 2022-03-06 17:03:38, INFO: extracting for polygon 2
# 2022-03-06 17:04:37, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.3.geojson
# 2022-03-06 17:04:37, INFO: extracting for polygon 3
# 2022-03-06 17:05:50, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.4.geojson
# 2022-03-06 17:05:50, INFO: extracting for polygon 4
# 2022-03-06 17:06:50, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.5.geojson
# 2022-03-06 17:06:50, INFO: extracting for polygon 5
# 2022-03-06 17:07:55, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.6.geojson
# 2022-03-06 17:07:55, INFO: extracting for polygon 6
# 2022-03-06 17:08:37, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.7.geojson
# 2022-03-06 17:08:37, INFO: extracting for polygon 7
# 2022-03-06 17:09:35, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.8.geojson
# 2022-03-06 17:09:35, INFO: extracting for polygon 8
# 2022-03-06 17:10:12, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.9.geojson
# 2022-03-06 17:10:12, INFO: extracting for polygon 9
# 2022-03-06 17:11:24, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.10.geojson
# 2022-03-06 17:11:24, INFO: extracting for polygon 10
# 2022-03-06 17:12:06, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.11.geojson
# 2022-03-06 17:12:06, INFO: extracting for polygon 11
# 2022-03-06 17:13:39, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.12.geojson
# 2022-03-06 17:13:39, INFO: extracting for polygon 12
# 2022-03-06 17:14:13, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.13.geojson
# 2022-03-06 17:14:13, INFO: extracting for polygon 13
# 2022-03-06 17:15:16, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.14.geojson
# 2022-03-06 17:15:16, INFO: extracting for polygon 14
# 2022-03-06 17:15:55, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.15.geojson
# 2022-03-06 17:15:55, INFO: extracting for polygon 15
# 2022-03-06 17:16:33, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.16.geojson
# 2022-03-06 17:16:33, INFO: extracting for polygon 16
# 2022-03-06 17:17:54, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.17.geojson
# 2022-03-06 17:17:54, INFO: extracting for polygon 17
# 2022-03-06 17:19:02, INFO: Exporting boundry file D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\boundary.18.geojson
# 2022-03-06 17:19:02, INFO: extracting for polygon 18

# %% [markdown]
# ## Step 2 - OSMNX Extraction
#
# Extracts complete OSM attributes using OSMNX.
# The input for this step is the polygon boundary file for the area.
# The output for this step is geojson files from OSMNX.

# %%
# the OSMNX extraction file is saved to the 'output_dir' argument

ranch.run_osmnx_extraction(
    input_polygon_file = input_polygon_file,
    output_dir = os.path.join(external_dir, "osmnx_extract")
)

# %% [markdown]
# ## Step 3 - Consolidate SharedStreets and OSMNX extractions
#
# consolidates raw roadway data and create initial roadway networks

# %%
# build and returns roadway network object from extraction files

metc_roadway_network = Roadway.create_roadway_network_from_extracts(
    shst_extract_dir = os.path.join(shst_extract_dir),
    osm_extract_dir = osm_extract_dir,
    parameters = parameters,
)
# Out:
# 2022-03-07 13:01:45, INFO: Reading sharedstreets data
# 2022-03-07 13:01:45, INFO: ----------start reading shst extraction data-------------
# 2022-03-07 13:01:45, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.0.out.geojson
# 2022-03-07 13:02:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.1.out.geojson
# 2022-03-07 13:02:36, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.10.out.geojson
# 2022-03-07 13:02:39, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.11.out.geojson
# 2022-03-07 13:02:44, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.12.out.geojson
# 2022-03-07 13:02:46, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.13.out.geojson
# 2022-03-07 13:02:48, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.14.out.geojson
# 2022-03-07 13:02:51, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.15.out.geojson
# 2022-03-07 13:02:55, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.16.out.geojson
# 2022-03-07 13:02:59, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.17.out.geojson
# 2022-03-07 13:03:20, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.18.out.geojson
# 2022-03-07 13:03:37, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.2.out.geojson
# 2022-03-07 13:03:49, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.3.out.geojson
# 2022-03-07 13:04:00, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.4.out.geojson
# 2022-03-07 13:04:04, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.5.out.geojson
# 2022-03-07 13:04:07, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.6.out.geojson
# 2022-03-07 13:04:42, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.7.out.geojson
# 2022-03-07 13:04:49, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.8.out.geojson
# 2022-03-07 13:04:52, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\sharedstreets_extract\extract.boundary.9.out.geojson
# 2022-03-07 13:04:55, INFO: ----------finished reading shst extraction data-------------
# 2022-03-07 13:04:55, INFO: Removing duplicates in shst extraction data
# 2022-03-07 13:04:55, INFO: ...before removing duplicates, shst extraction has 828629 geometries.
# 2022-03-07 13:04:58, INFO: ...after removing duplicates, shst extraction has 580232 geometries.
# 2022-03-07 13:04:58, INFO: Reading osmnx data
# 2022-03-07 13:22:02, INFO: Extracting corresponding osm ways for every shst geometry
# 2022-03-07 13:34:10, INFO: shst extraction has 576827 geometries
# 2022-03-07 13:34:10, INFO: shst extraction has 600848 osm links
# 2022-03-07 13:34:11, INFO: ---joining osm shst with osmnx data---
# 2022-03-07 13:34:15, INFO: shst extraction has 542067 two-way osm links
# 2022-03-07 13:34:16, INFO: and they are 522883 geometrys
# 2022-03-07 13:34:21, INFO: after join, ther are 1142915 osm links from shst extraction,     out of which there are 138447 links that do not have osm info,     due to shst extraction (default tile 181224) contains 47165 osm ids that are not included in latest OSM extraction,     e.g. private streets, closed streets.
# 2022-03-07 13:34:31, INFO: after join, there are 1099710 shst referencies
# 2022-03-07 13:34:32, INFO: numeric columns: ['wayId', 'u', 'v', 'osmid', 'key', 'reverse_out']
# 2022-03-07 13:34:33, INFO: str columns:
# 2022-03-07 13:34:40, INFO: Start aggregating osm segments to one shst link for forward links
# 2022-03-07 13:38:03, INFO: Start aggregating osm segments to one shst link for backward links
# 2022-03-07 13:41:00, INFO: all
# 2022-03-07 13:41:49, INFO: Start creating shst nodes
# 2022-03-07 13:43:10, INFO: Lasso base directory set as: D:/github/Ranch

# %%
RanchLogger.info("Initial network has {} links".format(metc_roadway_network.links_df.shape[0]))
RanchLogger.info("Initial network has {} nodes".format(metc_roadway_network.nodes_df.shape[0]))
RanchLogger.info("Initial network has {} shapes".format(metc_roadway_network.shapes_df.shape[0]))
# Out:
# 2022-03-07 14:20:54, INFO: Initial network has 1099287 links
# 2022-03-07 14:20:54, INFO: Initial network has 420408 nodes
# 2022-03-07 14:20:54, INFO: Initial network has 576818 shapes

# %% [markdown]
# ### Optional: If the user wants to write out the roadway network in standard format, they can do the following, otherwise no need to write out. These files can also be written out after step 5.  After step 5, roadway network is trimmed to be within county boundary

# %%
RanchLogger.info("write out shape geojson")

shape_prop = ['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId', 'backReferenceId']
shape_geojson = link_df_to_geojson(
    roadway_network.shapes_df, 
    shape_prop
)

with open(os.path.join(interim_dir,"step3_shapes.geojson"), "w") as f:
    json.dump(shape_geojson, f)

RanchLogger.info("write out node geojson")

node_prop = roadway_network.nodes_df.drop('geometry', axis = 1).columns.tolist()
node_geojson = point_df_to_geojson(
    roadway_network.nodes_df, 
    node_prop
)

with open(os.path.join(interim_dir,"step3_nodes.geojson"), "w") as f:
    json.dump(node_geojson, f)

RanchLogger.info("write out link json")

link_prop = roadway_network.links_df.drop(
    ['geometry'], 
    axis = 1
).columns.tolist()

out = roadway_network.links_df[link_prop].to_json(orient = "records")

with open(os.path.join(interim_dir,"step3_links.json"), 'w') as f:
    f.write(out)
    
# the standard format for links are links.json, without the geometry
# here writing out links in links.geojson in case the user wants to visualize links

RanchLogger.info("write out link geojson")

link_prop = roadway_network.links_df.drop('geometry', axis = 1).columns.tolist()
link_geojson = link_df_to_geojson(
    roadway_network.links_df, 
    link_prop
)

with open(os.path.join(interim_dir,"step3_links.geojson"), "w") as f:
    json.dump(link_geojson, f)

# %% [markdown]
# ### Optional: it's more efficient if the user writes out the intermediate network object in pickle

# %%
working_network_filename = os.path.join(interim_dir,"step3_network.pickle")
pickle.dump(metc_roadway_network, open(working_network_filename, 'wb'))

# %% [markdown]
# ## Step 4 - Third-Party Roadway Data Conflation
#
# Conflates e.g. county network with roadway network using SharedStreets.
# The input for this step is the 3rd-party geodatabases to conflate.
# The output of this step is the SharedStreets conflation outputs in geojson.

# %% [markdown]
# #### Metcouncil's reviewed version of base network

# %%
# define the input 3rd-party file, either shapefile or geojson

metc_network_file = os.path.join(external_dir, "rachel_corrected_version", "BaseNet_NoMnPASS.shp")

# %%
metc_network_gdf = gpd.read_file(metc_network_file)

# %%
metc_network_gdf.crs
# Out:
# <Projected CRS: EPSG:26915>
# Name: NAD83 / UTM zone 15N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 96°W and 90°W - onshore and offshore. Canada - Manitoba; Nunavut; Ontario. United States (USA) - Arkansas; Illinois; Iowa; Kansas; Louisiana; Michigan; Minnesota; Mississippi; Missouri; Nebraska; Oklahoma; Tennessee; Texas; Wisconsin.
# - bounds: (-96.0, 25.61, -90.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 15N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# conflate just the drive links, exclude centroid connectors

metc_network_gdf = metc_network_gdf[
    (metc_network_gdf.drive == 1) & 
    (metc_network_gdf.A > 3100) & 
    (metc_network_gdf.B > 3100)
]

# %%
metc_network_gdf[metc_network_gdf.geoId == '4a683887505ce9fd1f7a2be95f3956ca']
# Out:
#         link_id                             geoId  \
# 42634     42635  4a683887505ce9fd1f7a2be95f3956ca
# 104567   104568  4a683887505ce9fd1f7a2be95f3956ca
#
#                                 shape_id      A      B  distance   roadway  \
# 42634   7b041916e6fd3744a45497c9a30ce7ca  23578  49818  0.254237  tertiary
# 104567  e433e4c6ede17230343b758534cfee29  49818  23578  0.254237  tertiary
#
#                         name  drive  walk  ...  lanes_NT  m_lanes_AM  \
# 42634   East Travelers Trail      1     0  ...         2           0
# 104567  East Travelers Trail      1     0  ...         2           0
#
#         m_lanes_MD  m_lanes_PM m_lanes_NT  access_AM  access_MD  access_PM  \
# 42634            0           0          0       None       None       None
# 104567           0           0          0       None       None       None
#
#         access_NT                                           geometry
# 42634        None  LINESTRING (478906.009 4958547.454, 478892.066...
# 104567       None  LINESTRING (478551.595 4958343.009, 478580.945...
#
# [2 rows x 42 columns]

# %%
metc_network_gdf.county.value_counts(dropna = False)
# Out:
# 4     88223
# 5     37530
# 3     32847
# 1     30391
# 7     23361
# 22    14055
# 6     11861
# 2     11092
# 21    10794
# 17     9263
# 19     8680
# 18     7832
# 12     7632
# 15     7223
# 11     6467
# 13     6256
# 16     6118
# 14     5126
# 20     4998
# 10      204
# Name: county, dtype: int64

# %%
county_polygon_file = os.path.join(
    external_dir,
    "county", 
    "cb_2018_us_county_500k_withinMETC.geojson"
)

county_polygon_gdf = gpd.read_file(county_polygon_file)

# %%
for i in range(len(county_polygon_gdf)):
    
    boundary_gdf = gpd.read_file(os.path.join(external_dir, "sharedstreets_extract/boundary."+str(i)+".geojson"))
    
    metc_network_gdf = metc_network_gdf.to_crs(CRS('epsg:4269'))
    
    sub_gdf = metc_network_gdf[metc_network_gdf.intersects(boundary_gdf.geometry.unary_union)].copy()
    
    metc_input_network_file = os.path.join(
        external_dir, 'rachel_corrected_version', "shst_match", "county_"+str(i)+"_in.geojson"
    )
    
    sub_gdf[['A', 'B', "geometry"]].to_file(
        os.path.join(metc_input_network_file), 
        driver = "GeoJSON"
    )

# %%
for i in range(len(county_polygon_gdf)):
    metc_input_network_file = os.path.join(
        external_dir, 'rachel_corrected_version', "shst_match", "county_"+str(i)+"_in.geojson"
    )

    ranch.run_shst_match(
        input_network_file = metc_input_network_file,
        input_unique_id = ['A', 'B'],
        output_dir = os.path.join(external_dir, 'rachel_corrected_version', "shst_match"),
        custom_match_option = '--tile-hierarchy=8 --search-radius=1 --snap-intersections --follow-line-direction'
    )

# %% [markdown]
# #### Anoka lanes

# %%
anoka_county_network_file = os.path.join(
    external_dir, 'CountyLanes_3-27-19', 'Anoka', 'AnokaCo_Segments_032519.shp'
)

# %%
anoka_county_network_df = gpd.read_file(anoka_county_network_file)

# %%
anoka_county_network_df.crs
# Out:
# <Projected CRS: PROJCS["NAD_1983_Lambert_Conformal_Conic",GEOGCS[" ...>
# Name: NAD_1983_Lambert_Conformal_Conic
# Axis Info [cartesian]:
# - [east]: Easting (US survey foot)
# - [north]: Northing (US survey foot)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# check if there is unique ID
# Segment_ID is unique ID

print(anoka_county_network_df.shape)
print(anoka_county_network_df.Segment_ID.nunique())
# Out:
# (506, 51)
# 506

# %%
ranch.run_shst_match(
    input_network_file = anoka_county_network_file,
    input_unique_id = ['Segment_ID'],
    output_dir = os.path.join(external_dir, 'CountyLanes_3-27-19', 'Anoka', "shst_match"),
    custom_match_option = '--tile-hierarchy=8 --search-radius=50 --snap-intersections'
)
# Out:
# here

# %% [markdown]
# #### Hennepin lanes

# %%
hennepin_county_network_file = os.path.join(
    external_dir, 'CountyLanes_3-27-19', 'Hennepin', 'Roadway_Width_032619.shp'
)

# %%
hennepin_county_network_df = gpd.read_file(hennepin_county_network_file)

# %%
hennepin_county_network_df.crs
# Out:
# <Projected CRS: PROJCS["HENNEPIN COUNTY",GEOGCS["GCS_User_Defined" ...>
# Name: HENNEPIN COUNTY
# Axis Info [cartesian]:
# - [east]: Easting (US survey foot)
# - [north]: Northing (US survey foot)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: D_User_Defined
# - Ellipsoid: User_Defined_Spheroid
# - Prime Meridian: Greenwich

# %%
# check if there is unique ID
# MAPIDINT is unique ID

print(hennepin_county_network_df.shape)
print(hennepin_county_network_df.MAPIDINT.nunique())
# Out:
# (3033, 10)
# 3033

# %%
ranch.run_shst_match(
    input_network_file = hennepin_county_network_file,
    input_unique_id = ['MAPIDINT'],
    output_dir = os.path.join(external_dir, 'CountyLanes_3-27-19', 'Hennepin', "shst_match"),
    custom_match_option = '--tile-hierarchy=8 --search-radius=50 --snap-intersections'
)

# %% [markdown]
# #### Carver lanes

# %%
carver_county_network_file = os.path.join(
    external_dir, 'CountyLanes_3-27-19', 'Carver County', 'Carver_export.shp'
)

# %%
carver_county_network_df = gpd.read_file(carver_county_network_file)

# %%
# check if there is unique ID
# OBJECTID is unique ID

print(carver_county_network_df.shape)
print(carver_county_network_df.OBJECTID.nunique())
# Out:
# (95, 9)
# 95

# %%
# carver network is 3D, need to reduce dimension
from shapely.geometry import LineString

carver_county_network_df['geometry'] = carver_county_network_df['geometry'].apply(
    lambda g: LineString([xy[:2] for xy in list(g.coords)])
)

# %%
carver_county_network_df.to_file(
    os.path.join(
    external_dir, 'CountyLanes_3-27-19', 'Carver County', 'Carver_export.geojson',
    ),
    driver='GeoJSON'
)

# %%
ranch.run_shst_match(
    input_network_file = os.path.join(
    external_dir, 'CountyLanes_3-27-19', 'Carver County', 'Carver_export.geojson',
    ),
    input_unique_id = ['OBJECTID'],
    output_dir = os.path.join(external_dir, 'CountyLanes_3-27-19', 'Carver County', "shst_match"),
    custom_match_option = '--tile-hierarchy=8 --search-radius=50 --snap-intersections'
)

# %% [markdown]
# #### Dakota lanes

# %%
dakota_county_network_file = os.path.join(
    external_dir, 'CountyLanes_3-27-19', 'Dakota', 'Dakota_export.shp'
)

# %%
dakota_county_network_df = gpd.read_file(dakota_county_network_file)

# %%
# check if there is unique ID
# OBJECTID is unique ID

print(dakota_county_network_df.shape)
print(dakota_county_network_df.OBJECTID.nunique())
# Out:
# (499, 15)
# 499

# %%
ranch.run_shst_match(
    input_network_file = dakota_county_network_file,
    input_unique_id = ['OBJECTID'],
    output_dir = os.path.join(external_dir, 'CountyLanes_3-27-19', 'Dakota', "shst_match"),
    custom_match_option = '--tile-hierarchy=8 --search-radius=50 --snap-intersections'
)

# %% [markdown]
# #### Washington lanes

# %%
washington_county_network_file = os.path.join(
    external_dir, 'WCNumberofLanesApril2019', 'WCNumberofLanesApril2019.shp'
)

# %%
washington_county_network_df = gpd.read_file(washington_county_network_file)

# %%
# check if there is unique ID
# NO unique ID

print(washington_county_network_df.shape)
print(washington_county_network_df.Rd_Number.nunique())
# Out:
# (642, 12)
# 53

# %%
ranch.run_shst_match(
    input_network_file = washington_county_network_file,
    #input_unique_id = ['MAPIDINT'],
    output_dir = os.path.join(external_dir, 'WCNumberofLanesApril2019', "shst_match"),
    custom_match_option = '--tile-hierarchy=8 --search-radius=50 --snap-intersections'
)
# Out:
# 2022-03-20 18:07:51, INFO: Input network for shst match does not have unique IDs, generating unique IDs
# 2022-03-20 18:07:51, INFO: Generated 642 unique IDs for 642 links in the input network
# 2022-03-20 18:07:51, INFO: Exporting shst match input - ID-ed geometry file D:/metcouncil_network_rebuild\data\external\WCNumberofLanesApril2019\shst_match\WCNumberofLanesApril2019.geojson
# 2022-03-20 18:07:52, INFO: Exporting ID-ed network file D:/metcouncil_network_rebuild\data\external\WCNumberofLanesApril2019\shst_match\WCNumberofLanesApril2019.full.geojson

# %% [markdown]
# #### MDOT lanes

# %%
mdot_lanes_network_file = os.path.join(
    external_dir, 'shp_trans_lanes', 'Export_Output.shp'
)

# %%
mdot_lanes_network_df = gpd.read_file(mdot_lanes_network_file)

# %%
mdot_lanes_network_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 174621 entries, 0 to 174620
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   OBJECTID    174621 non-null  int64
#  1   FROM_DATE   174621 non-null  object
#  2   TO_DATE     39439 non-null   object
#  3   EVENT_ID    174621 non-null  object
#  4   ROUTE_ID    174621 non-null  object
#  5   FROM_MEASU  174621 non-null  float64
#  6   TO_MEASURE  174621 non-null  float64
#  7   EDITED_BY   81894 non-null   object
#  8   EDITED_DAT  81894 non-null   object
#  9   THROUGH_LA  174621 non-null  int64
#  10  ACCURACY_S  174621 non-null  int64
#  11  LOCERROR    174621 non-null  object
#  12  COUNTY_NAM  174621 non-null  object
#  13  COUNTY_COD  174621 non-null  object
#  14  SHAPE_Leng  174621 non-null  float64
#  15  geometry    174621 non-null  geometry
# dtypes: float64(3), geometry(1), int64(3), object(9)
# memory usage: 21.3+ MB

# %%
# check if there is unique ID
# OBJECTID is unique ID

print(mdot_lanes_network_df.shape)
print(mdot_lanes_network_df.OBJECTID.nunique())
# Out:
# (174621, 16)
# 174621

# %%
for i in range(len(county_polygon_gdf)):
    
    boundary_gdf = gpd.read_file(os.path.join(external_dir, "sharedstreets_extract/boundary."+str(i)+".geojson"))
    
    mdot_lanes_network_df = mdot_lanes_network_df.to_crs(CRS('epsg:4269'))
    
    sub_gdf = mdot_lanes_network_df[mdot_lanes_network_df.intersects(boundary_gdf.geometry.unary_union)].copy()
    
    mdot_lanes_input_network_file = os.path.join(
        external_dir, 'shp_trans_lanes', "shst_match", "county_"+str(i)+"_in.geojson"
    )
    
    sub_gdf[['OBJECTID', "geometry"]].to_file(
        os.path.join(mdot_lanes_input_network_file), 
        driver = "GeoJSON"
    )

# %%
for i in range(len(county_polygon_gdf)):
    mdot_lanes_input_network_file = os.path.join(
        external_dir, 'shp_trans_lanes', "shst_match", "county_"+str(i)+"_in.geojson"
    )

    ranch.run_shst_match(
        input_network_file = mdot_lanes_input_network_file,
        input_unique_id = ['A', 'B'],
        output_dir = os.path.join(external_dir, 'shp_trans_lanes', "shst_match"),
        custom_match_option = '--tile-hierarchy=8 --search-radius=10 --snap-intersections'
    )

# %%
mdot_lanes_network_df[mdot_lanes_network_df.OBJECTID.isin([153616, 153823])]
# Out:
#         OBJECTID   FROM_DATE TO_DATE EVENT_ID            ROUTE_ID  FROM_MEASU  \
# 153615    153616  2014-01-28    None   145064  0400006595110011-D    4.749351
# 153822    153823  2014-01-28    None     5143  0400006595110011-I    4.749351
#
#         TO_MEASURE    EDITED_BY  EDITED_DAT  THROUGH_LA  ACCURACY_S  LOCERROR  \
# 153615    5.833757  AD\dewi1mic  2017-06-15           1           0  NO ERROR
# 153822    5.833757  AD\dewi1mic  2017-06-15           1           0  NO ERROR
#
#        COUNTY_NAM COUNTY_COD   SHAPE_Leng  \
# 153615       Rice         66  1745.185063
# 153822       Rice         66  1745.185063
#
#                                                  geometry
# 153615  LINESTRING Z (-93.31266 44.30009 0.00000, -93....
# 153822  LINESTRING Z (-93.31266 44.30009 0.00000, -93....

# %% [markdown]
# #### WDOT lanes

# %% [markdown]
# #### MDOT roadway type

# %% [markdown]
# #### WDOT roadway type

# %% [markdown]
# ## Step 5 - Tidy Up Roadway
#
# Trim network to be within county boundary. Identifies drive dead-ends, cul-de-secs, numbering links and nodes, etc.
# The input for this step is the polygon file with subregion identifier, e.g. county.
# This step labels each link and node with the county name.

# %%
# the roadway_network used for step 6 should be the entire region's network

step3_network_filename = os.path.join(
    interim_dir, 'step3_network.pickle'
)

metc_roadway_network = pickle.load(open(step3_network_filename, 'rb'))

# %%
# this is the input county polygon file with county names

county_boundary_file = os.path.join(
    external_dir,
    "county", 
    "cb_2018_us_county_500k_withinMETC.geojson"
)

# specify the column to look for county name

county_variable_name = 'NAME'

# %%
metc_roadway_network.parameters.model_centroid_node_id_reserve = 3100

# %%
metc_roadway_network.parameters

# %%
metc_roadway_network.parameters.model_centroid_node_id_reserve
# Out:
# 3100

# %%
metc_roadway_network.tidy_roadway(
    county_boundary_file = county_boundary_file,
    county_variable_name = county_variable_name,
    create_node_link_id = True,
    county_based_numbering = False
)
# Out:
# 2022-03-16 14:44:33, INFO: Starting Step 5 Tidy Roadway
# 2022-03-16 14:46:50, INFO: Joining network with county boundary file for ['Hennepin' 'Scott' 'Washington' 'Wright' 'Sherburne' 'Rice' 'Ramsey'
#  'Carver' 'Isanti' 'Pierce' 'McLeod' 'Goodhue' 'Le Sueur' 'Sibley'
#  'Chisago' 'St. Croix' 'Polk' 'Dakota' 'Anoka'] county
# 2022-03-16 14:49:11, INFO: Dropping links and nodes that are outside of ['Isanti' 'Dakota' 'Hennepin' 'Sibley' 'Carver' 'St. Croix' 'Washington'
#  'Ramsey' 'Anoka' 'Le Sueur' 'Wright' 'Polk' 'Rice' 'Scott' 'Goodhue'
#  'Chisago' 'McLeod' 'Sherburne' 'Pierce'] county
# 2022-03-16 14:49:17, INFO: Droppping circular links
# 2022-03-16 14:49:20, INFO: Flagging dead-end streets for drive network
# 2022-03-16 14:49:36, INFO: Making dead-end streets drive_access = 0
# 2022-03-16 14:50:47, INFO: Dropping alternative links between same AB nodes
# 2022-03-16 14:51:35, INFO: Numbering links and nodes using county based rules

# %%
RanchLogger.info("Initial network has {} links".format(metc_roadway_network.links_df.shape[0]))
RanchLogger.info("Initial network has {} nodes".format(metc_roadway_network.nodes_df.shape[0]))
RanchLogger.info("Initial network has {} shapes".format(metc_roadway_network.shapes_df.shape[0]))
# Out:
# 2022-03-16 14:51:54, INFO: Initial network has 1056575 links
# 2022-03-16 14:51:54, INFO: Initial network has 412227 nodes
# 2022-03-16 14:51:54, INFO: Initial network has 553939 shapes

# %%
# save out the step 5 output as pickle file

working_network_filename = os.path.join(interim_dir,"step5_network.pickle")
pickle.dump(metc_roadway_network, open(working_network_filename, 'wb'))

# %%
# check if missing IDs

# if node missing shst id
print(metc_roadway_network.nodes_df.shst_node_id.isnull().sum())
print(metc_roadway_network.nodes_df.shst_node_id.nunique())
# if node missing osm id
print(metc_roadway_network.nodes_df.osm_node_id.isnull().sum())
# if node missing osm id
print(metc_roadway_network.nodes_df.osm_node_id.dtype)
print(metc_roadway_network.nodes_df[metc_roadway_network.nodes_df.osm_node_id == 0])
print(metc_roadway_network.nodes_df.osm_node_id.nunique())
# if node missing model node id
print(metc_roadway_network.nodes_df.model_node_id.nunique())

# if link missing 
print(metc_roadway_network.links_df.shstReferenceId.isnull().sum())
print(metc_roadway_network.links_df.shstReferenceId.nunique())
print(metc_roadway_network.links_df.model_link_id.nunique())

# if link missing node id
print(metc_roadway_network.links_df.fromIntersectionId.isnull().sum())
print(metc_roadway_network.links_df.toIntersectionId.isnull().sum())
print(metc_roadway_network.links_df.u.isnull().sum())
print(metc_roadway_network.links_df[metc_roadway_network.links_df.u == 0])
print(metc_roadway_network.links_df.v.isnull().sum())
print(metc_roadway_network.links_df[metc_roadway_network.links_df.v == 0])
print(len(set(metc_roadway_network.links_df.v.tolist() + metc_roadway_network.links_df.u.tolist())))
# Out:
# 0
# 412227
# 0
# int64
# Empty GeoDataFrame
# Columns: [osm_node_id, shst_node_id, geometry, county, drive_access, walk_access, bike_access, model_node_id]
# Index: []
# 412227
# 412227
# 0
# 1056575
# 1056575
# 0
# 0
# 0
# Empty GeoDataFrame
# Columns: [shstReferenceId, id, shstGeometryId, fromIntersectionId, toIntersectionId, geometry, u, v, nodeIds, wayId, roadClass, oneWay, roundabout, link, oneway, lanes, ref, name, highway, service, width, maxspeed, access, junction, bridge, tunnel, landuse, area, key, forward, roadway, drive_access, walk_access, bike_access, county, length, model_link_id, A, B]
# Index: []
#
# [0 rows x 39 columns]
# 0
# Empty GeoDataFrame
# Columns: [shstReferenceId, id, shstGeometryId, fromIntersectionId, toIntersectionId, geometry, u, v, nodeIds, wayId, roadClass, oneWay, roundabout, link, oneway, lanes, ref, name, highway, service, width, maxspeed, access, junction, bridge, tunnel, landuse, area, key, forward, roadway, drive_access, walk_access, bike_access, county, length, model_link_id, A, B]
# Index: []
#
# [0 rows x 39 columns]
# 412227

# %%
# for visual checking

RanchLogger.info("write out node geojson")

node_prop = metc_roadway_network.nodes_df.drop('geometry', axis = 1).columns.tolist()
node_geojson = point_df_to_geojson(
    metc_roadway_network.nodes_df, 
    node_prop
)

with open(os.path.join(interim_dir,"step5_nodes.geojson"), "w") as f:
    json.dump(node_geojson, f)


# the standard format for links are links.json, without the geometry
# here writing out links in links.geojson in case the user wants to visualize links

RanchLogger.info("write out link geojson")

link_prop = metc_roadway_network.links_df.drop('geometry', axis = 1).columns.tolist()
link_geojson = link_df_to_geojson(
    metc_roadway_network.links_df, 
    link_prop
)

with open(os.path.join(interim_dir,"step5_links.geojson"), "w") as f:
    json.dump(link_geojson, f)
# Out:
# 2022-03-08 14:53:47, INFO: write out node geojson
# 2022-03-08 14:54:51, INFO: write out link geojson

# %% [markdown]
# ## Step 6 - Build Transit Network from GTFS
#
# Build standard transit network from GTFS

# %%
parameters.model_time_period = {
    "pk": {"start": 6, "end": 9},
    "op": {"start": 9, "end": 15},
}

parameters.model_time_enum_list = {
    "start_time": {
        "pk": "06:00:00",
        "op": "09:00:00",
    },
    "end_time": {
        "pk": "09:00:00",
        "op": "15:00:00",
    },
}

# %%
# the directory where all gtfs feeds are located
# e.g. gtfs_dir/sjrtd_2015_0127/routes.txt
# e.g. gtfs_dir/bart_2015_0127/routes.txt

gtfs_dir = os.path.join(external_dir, "gtfs")

# %%
# read gtfs into transit object

transit_network = Transit.load_all_gtfs_feeds(
    gtfs_dir = gtfs_dir,
    roadway_network= metc_roadway_network,
    parameters=parameters
)
# Out:
# 2022-03-11 19:39:11, INFO: Excluding weekend-only services
# 2022-03-11 19:39:11, INFO: Read and get representative transit feed from: D:/metcouncil_network_rebuild\data\external\gtfs\MT2019
# 2022-03-11 19:39:26, INFO: Excluding weekend-only services
# 2022-03-11 19:39:26, INFO: Read and get representative transit feed from: D:/metcouncil_network_rebuild\data\external\gtfs\MV2019
# 2022-03-11 19:39:29, INFO: Lasso base directory set as: D:/github/Ranch

# %%
# main activities - routing buses, creating rails

transit_network.build_standard_transit_network(
    num_most_pattern = 2,
    multithread_shst_match = True,
    multithread_shortest_path = False,
)
# Out:
# 2022-03-11 19:39:29, INFO: Getting representative trip for each route by time of day and direction...
#      route_id                service_id                            trip_id  \
# 5689   515-95  AUG19-MVS-BUS-Weekday-01  15289929-AUG19-MVS-BUS-Weekday-01
# 5692   515-95  AUG19-MVS-BUS-Weekday-01  15289930-AUG19-MVS-BUS-Weekday-01
# 5698   515-95  AUG19-MVS-BUS-Weekday-01  15289937-AUG19-MVS-BUS-Weekday-01
# 5706   515-95  AUG19-MVS-BUS-Weekday-01  15289949-AUG19-MVS-BUS-Weekday-01
# 5742   515-95  AUG19-MVS-BUS-Weekday-01  15289970-AUG19-MVS-BUS-Weekday-01
# 5748   515-95  AUG19-MVS-BUS-Weekday-01  15289974-AUG19-MVS-BUS-Weekday-01
# 5754   515-95  AUG19-MVS-BUS-Weekday-01  15289978-AUG19-MVS-BUS-Weekday-01
# 5757   515-95  AUG19-MVS-BUS-Weekday-01  15289980-AUG19-MVS-BUS-Weekday-01
#
#                                          trip_headsign  direction_id block_id  \
# 5689            Eastbound 515E  66th St / Vets Med Ctr             0     1930
# 5692   Eastbound 515C  66th St / Mall Amer / Bloom Ave             0     1928
# 5698   Eastbound 515C  66th St / Mall Amer / Bloom Ave             0     1927
# 5706  Eastbound 515B  66th St / Mall Amer / Longfellow             0     1931
# 5742    Westbound 515  66th St / Southdale / Bloom Ave             1     1929
# 5748    Westbound 515  66th St / Southdale / Bloom Ave             1     1929
# 5754   Westbound 515  66th St / Southdale / Longfellow             1     1929
# 5757   Westbound 515  66th St / Southdale / Longfellow             1     1930
#
#      shape_id  wheelchair_accessible agency_raw_name trip_destination  ...  \
# 5689  5150005                    1.0          MT2019              NaN  ...
# 5692  5150002                    1.0          MT2019              NaN  ...
# 5698  5150002                    1.0          MT2019              NaN  ...
# 5706  5150006                    1.0          MT2019              NaN  ...
# 5742  5150003                    1.0          MT2019              NaN  ...
# 5748  5150003                    1.0          MT2019              NaN  ...
# 5754  5150001                    1.0          MT2019              NaN  ...
# 5757  5150001                    1.0          MT2019              NaN  ...
#
#      arrival_m departure_h departure_m tod  index  trip_num_for_shape  \
# 5689        23           6          23  pk   1112                   3
# 5692        38           6          38  pk   1111                   6
# 5698        23           9          23  op   1120                   8
# 5706        38           9          38  op   1119                  10
# 5742        45           6          45  pk   1109                   6
# 5748        14           9          14  op   1118                   6
# 5754         2           8           2  pk   1110                   3
# 5757        31           9          31  op   1117                  11
#
#      trip_num_total  num_pattern  trip_num_N_most number_of_stops
# 5689             12            2                9              46
# 5692             12            2                9              50
# 5698             24            2               18              50
# 5706             24            2               18              34
# 5742             12            2                9              49
# 5748             23            2               17              49
# 5754             12            2                9              33
# 5757             23            2               17              33
#
# [8 rows x 34 columns]
# 2022-03-11 19:39:30, INFO: Snapping gtfs stops to roadway node...
# 2022-03-11 19:41:50, INFO: Route bus trips using shortest path
# 2022-03-11 19:41:52, INFO: Routing bus on roadway network from start to end with osmnx...
# 2022-03-11 19:41:53, INFO: Setting good link dictionary
# 2022-03-11 19:44:04, INFO: 	Routing agency MT2019, trip 15245259-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:44:41, INFO: 	Routing agency MT2019, trip 15248272-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:45:13, INFO: 	Routing agency MT2019, trip 15245245-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:45:58, INFO: 	Routing agency MT2019, trip 15248215-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:46:29, INFO: 	Routing agency MT2019, trip 15248109-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:47:02, INFO: 	Routing agency MT2019, trip 15245270-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:47:29, INFO: 	Routing agency MT2019, trip 15288269-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:47:55, INFO: 	Routing agency MT2019, trip 15248116-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:48:31, INFO: 	Routing agency MT2019, trip 15289515-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:49:03, INFO: 	Routing agency MT2019, trip 15248055-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:49:49, INFO: 	Routing agency MT2019, trip 15245030-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:50:31, INFO: 	Routing agency MT2019, trip 15245075-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:51:11, INFO: 	Routing agency MT2019, trip 15244221-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:51:44, INFO: 	Routing agency MT2019, trip 15288232-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:52:08, INFO: 	Routing agency MT2019, trip 15289626-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:52:41, INFO: 	Routing agency MT2019, trip 15248113-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:53:28, INFO: 	Routing agency MT2019, trip 15248106-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:54:05, INFO: 	Routing agency MT2019, trip 15251239-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:54:31, INFO: 	Routing agency MT2019, trip 15248059-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:55:08, INFO: 	Routing agency MT2019, trip 15244298-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:55:40, INFO: 	Routing agency MT2019, trip 15248069-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:56:17, INFO: 	Routing agency MT2019, trip 15288223-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:56:51, INFO: 	Routing agency MT2019, trip 15249348-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:57:16, INFO: 	Routing agency MT2019, trip 15245028-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:57:55, INFO: 	Routing agency MT2019, trip 15245066-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:58:34, INFO: 	Routing agency MT2019, trip 15244121-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:59:07, INFO: 	Routing agency MT2019, trip 15244083-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 19:59:41, INFO: 	Routing agency MT2019, trip 15248277-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:00:20, INFO: 	Routing agency MT2019, trip 15244245-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:00:52, INFO: 	Routing agency MT2019, trip 15247182-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:01:27, INFO: 	Routing agency MT2019, trip 15248213-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:01:56, INFO: 	Routing agency MT2019, trip 15247187-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:02:34, INFO: 	Routing agency MT2019, trip 15247135-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:03:12, INFO: 	Routing agency MT2019, trip 15249374-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:03:45, INFO: 	Routing agency MT2019, trip 15246544-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:04:19, INFO: 	Routing agency MT2019, trip 15244296-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:04:51, INFO: 	Routing agency MT2019, trip 15251355-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:05:18, INFO: 	Routing agency MT2019, trip 15250304-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:05:47, INFO: 	Routing agency MT2019, trip 15246537-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:06:21, INFO: 	Routing agency MT2019, trip 15247127-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:07:10, INFO: 	Routing agency MT2019, trip 15762185-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:07:41, INFO: 	Routing agency MT2019, trip 15245692-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:08:04, INFO: 	Routing agency MT2019, trip 15285229-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:08:33, INFO: 	Routing agency MT2019, trip 15285204-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:09:02, INFO: 	Routing agency MT2019, trip 15244077-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:09:33, INFO: 	Routing agency MT2019, trip 15289658-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:10:00, INFO: 	Routing agency MT2019, trip 15289657-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:10:28, INFO: 	Routing agency MT2019, trip 15246536-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:11:11, INFO: 	Routing agency MT2019, trip 15285217-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:11:39, INFO: 	Routing agency MT2019, trip 15249345-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:12:01, INFO: 	Routing agency MT2019, trip 15244684-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:12:31, INFO: 	Routing agency MT2019, trip 15289512-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:12:58, INFO: 	Routing agency MT2019, trip 15244113-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:13:29, INFO: 	Routing agency MT2019, trip 15285257-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:13:57, INFO: 	Routing agency MT2019, trip 15245153-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:14:38, INFO: 	Routing agency MT2019, trip 15245102-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:15:08, INFO: 	Routing agency MT2019, trip 15289618-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:15:36, INFO: 	Routing agency MT2019, trip 15245290-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:16:00, INFO: 	Routing agency MT2019, trip 15248913-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:16:30, INFO: 	Routing agency MT2019, trip 15250299-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:16:57, INFO: 	Routing agency MT2019, trip 15248873-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:17:28, INFO: 	Routing agency MT2019, trip 15250295-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:18:07, INFO: 	Routing agency MT2019, trip 15251214-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:18:28, INFO: 	Routing agency MT2019, trip 15245293-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:18:50, INFO: 	Routing agency MT2019, trip 15285289-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:19:25, INFO: 	Routing agency MT2019, trip 15248394-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:19:41, INFO: 	Routing agency MT2019, trip 15415147-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:20:18, INFO: 	Routing agency MT2019, trip 15285273-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:20:46, INFO: 	Routing agency MT2019, trip 15244665-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:21:30, INFO: 	Routing agency MT2019, trip 15415171-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:22:06, INFO: 	Routing agency MT2019, trip 15251257-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:22:26, INFO: 	Routing agency MT2019, trip 15249854-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:22:42, INFO: 	Routing agency MT2019, trip 15288263-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:23:05, INFO: 	Routing agency MT2019, trip 15245921-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:23:36, INFO: 	Routing agency MT2019, trip 15245934-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:24:07, INFO: 	Routing agency MT2019, trip 15415172-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:24:44, INFO: 	Routing agency MT2019, trip 15284939-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:25:22, INFO: 	Routing agency MT2019, trip 15284940-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:25:51, INFO: 	Routing agency MT2019, trip 15287203-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:26:16, INFO: 	Routing agency MT2019, trip 15244485-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:26:37, INFO: 	Routing agency MT2019, trip 15287214-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:27:00, INFO: 	Routing agency MT2019, trip 15248201-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:27:28, INFO: 	Routing agency MT2019, trip 15244523-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:27:52, INFO: 	Routing agency MT2019, trip 15415153-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:28:37, INFO: 	Routing agency MT2019, trip 15293753-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:29:14, INFO: 	Routing agency MT2019, trip 15285290-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:29:49, INFO: 	Routing agency MT2019, trip 15284942-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:30:19, INFO: 	Routing agency MT2019, trip 15249855-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:30:34, INFO: 	Routing agency MT2019, trip 15248374-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:30:50, INFO: 	Routing agency MT2019, trip 15245482-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:31:14, INFO: 	Routing agency MT2019, trip 15251661-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:31:28, INFO: 	Routing agency MT2019, trip 15415150-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:32:13, INFO: 	Routing agency MT2019, trip 15248395-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:32:28, INFO: 	Routing agency MT2019, trip 15251639-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:32:45, INFO: 	Routing agency MT2019, trip 15293740-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:33:22, INFO: 	Routing agency MT2019, trip 15244525-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:33:44, INFO: 	Routing agency MT2019, trip 15244231-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:34:07, INFO: 	Routing agency MT2019, trip 15251627-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:34:25, INFO: 	Routing agency MT2019, trip 15244659-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:35:00, INFO: 	Routing agency MT2019, trip 15293732-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:35:37, INFO: 	Routing agency MT2019, trip 15244702-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:36:17, INFO: 	Routing agency MT2019, trip 15288317-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:36:40, INFO: 	Routing agency MT2019, trip 15244770-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:37:10, INFO: 	Routing agency MT2019, trip 15244699-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:37:36, INFO: 	Routing agency MT2019, trip 15245188-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:38:06, INFO: 	Routing agency MT2019, trip 15244284-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:38:29, INFO: 	Routing agency MT2019, trip 15251664-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:38:43, INFO: 	Routing agency MT2019, trip 15245949-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:39:12, INFO: 	Routing agency MT2019, trip 15250636-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:39:38, INFO: 	Routing agency MT2019, trip 15250653-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:39:54, INFO: 	Routing agency MT2019, trip 15248370-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:40:08, INFO: 	Routing agency MT2019, trip 15247511-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:40:34, INFO: 	Routing agency MT2019, trip 15293744-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:41:12, INFO: 	Routing agency MT2019, trip 15244663-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:41:44, INFO: 	Routing agency MT2019, trip 15250305-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:42:08, INFO: 	Routing agency MT2019, trip 15245189-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:42:36, INFO: 	Routing agency MT2019, trip 15244666-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:43:20, INFO: 	Routing agency MT2019, trip 15244660-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:43:54, INFO: 	Routing agency MT2019, trip 15289503-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:44:19, INFO: 	Routing agency MT2019, trip 15250957-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:44:51, INFO: 	Routing agency MT2019, trip 15287200-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:45:13, INFO: 	Routing agency MT2019, trip 15287201-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:45:35, INFO: 	Routing agency MT2019, trip 15245097-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:46:04, INFO: 	Routing agency MT2019, trip 15245132-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:46:30, INFO: 	Routing agency MT2019, trip 15250491-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:47:15, INFO: 	Routing agency MT2019, trip 15247671-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:47:44, INFO: 	Routing agency MT2019, trip 15247713-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:48:14, INFO: 	Routing agency MT2019, trip 15244758-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:48:38, INFO: 	Routing agency MT2019, trip 15244647-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:49:11, INFO: 	Routing agency MT2019, trip 15248939-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:49:44, INFO: 	Routing agency MT2019, trip 15250302-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:50:18, INFO: 	Routing agency MT2019, trip 15250643-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:50:34, INFO: 	Routing agency MT2019, trip 15250301-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:50:58, INFO: 	Routing agency MT2019, trip 15244191-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:51:26, INFO: 	Routing agency MT2019, trip 15245709-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:51:46, INFO: 	Routing agency MT2019, trip 15285194-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:52:11, INFO: 	Routing agency MT2019, trip 15244479-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:52:31, INFO: 	Routing agency MT2019, trip 15250659-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:52:48, INFO: 	Routing agency MT2019, trip 15248966-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:53:20, INFO: 	Routing agency MT2019, trip 15247524-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:53:47, INFO: 	Routing agency MT2019, trip 15245566-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:54:17, INFO: 	Routing agency MT2019, trip 15244690-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:54:39, INFO: 	Routing agency MT2019, trip 15247261-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:55:03, INFO: 	Routing agency MT2019, trip 15247527-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:55:30, INFO: 	Routing agency MT2019, trip 15245920-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:56:01, INFO: 	Routing agency MT2019, trip 15246238-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:56:26, INFO: 	Routing agency MT2019, trip 15245330-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:56:47, INFO: 	Routing agency MT2019, trip 15249691-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:57:11, INFO: 	Routing agency MT2019, trip 15246209-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:57:46, INFO: 	Routing agency MT2019, trip 15247243-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:58:10, INFO: 	Routing agency MT2019, trip 15245908-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:58:40, INFO: 	Routing agency MT2019, trip 15273501-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 20:58:51, INFO: 	Routing agency MT2019, trip 15245947-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:59:20, INFO: 	Routing agency MT2019, trip 15245324-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 20:59:42, INFO: 	Routing agency MT2019, trip 15244241-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:00:04, INFO: 	Routing agency MT2019, trip 15249283-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:00:29, INFO: 	Routing agency MT2019, trip 15251393-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:01:04, INFO: 	Routing agency MT2019, trip 15288493-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:01:35, INFO: 	Routing agency MT2019, trip 15250136-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:02:08, INFO: 	Routing agency MT2019, trip 15284943-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:02:30, INFO: 	Routing agency MT2019, trip 15249346-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:02:51, INFO: 	Routing agency MT2019, trip 15762181-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:03:19, INFO: 	Routing agency MT2019, trip 15246063-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:03:42, INFO: 	Routing agency MT2019, trip 15249235-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:04:07, INFO: 	Routing agency MT2019, trip 15251465-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:04:20, INFO: 	Routing agency MT2019, trip 15244539-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:04:40, INFO: 	Routing agency MT2019, trip 15273511-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 21:05:19, INFO: 	Routing agency MT2019, trip 15249694-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:05:45, INFO: 	Routing agency MT2019, trip 15244977-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:06:07, INFO: 	Routing agency MT2019, trip 15245991-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:06:29, INFO: 	Routing agency MT2019, trip 15293320-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:07:03, INFO: 	Routing agency MT2019, trip 15248858-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:07:29, INFO: 	Routing agency MT2019, trip 15249276-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:07:53, INFO: 	Routing agency MT2019, trip 15288222-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:08:13, INFO: 	Routing agency MT2019, trip 15251086-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:08:27, INFO: 	Routing agency MT2019, trip 15273564-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 21:09:05, INFO: 	Routing agency MT2019, trip 15249769-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:09:21, INFO: 	Routing agency MT2019, trip 15250672-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:09:45, INFO: 	Routing agency MT2019, trip 15250667-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:10:09, INFO: 	Routing agency MT2019, trip 15245000-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:10:31, INFO: 	Routing agency MT2019, trip 15244961-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:10:53, INFO: 	Routing agency MT2019, trip 15246198-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:11:16, INFO: 	Routing agency MT2019, trip 15246024-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:11:36, INFO: 	Routing agency MT2019, trip 15245172-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:11:50, INFO: 	Routing agency MT2019, trip 15249239-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:12:15, INFO: 	Routing agency MT2019, trip 15250313-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:12:48, INFO: 	Routing agency MT2019, trip 15251152-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:13:07, INFO: 	Routing agency MT2019, trip 15251153-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:13:26, INFO: 	Routing agency MT2019, trip 15762182-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:13:55, INFO: 	Routing agency MT2019, trip 15251420-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:14:22, INFO: 	Routing agency MT2019, trip 15249304-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:14:46, INFO: 	Routing agency MT2019, trip 15251155-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:15:04, INFO: 	Routing agency MT2019, trip 15251154-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:15:23, INFO: 	Routing agency MT2019, trip 15251150-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:15:46, INFO: 	Routing agency MT2019, trip 15287174-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:16:25, INFO: 	Routing agency MT2019, trip 15273459-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 21:16:54, INFO: 	Routing agency MT2019, trip 15249792-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:17:08, INFO: 	Routing agency MT2019, trip 15250536-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:17:31, INFO: 	Routing agency MT2019, trip 15251476-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:17:44, INFO: 	Routing agency MT2019, trip 15251421-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:18:08, INFO: 	Routing agency MT2019, trip 15251053-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:18:23, INFO: 	Routing agency MT2019, trip 15251362-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:18:42, INFO: 	Routing agency MT2019, trip 15245252-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:19:04, INFO: 	Routing agency MT2019, trip 15273580-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 21:19:15, INFO: 	Routing agency MT2019, trip 15284993-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:19:36, INFO: 	Routing agency MT2019, trip 15250504-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:20:09, INFO: 	Routing agency MT2019, trip 15250525-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:20:32, INFO: 	Routing agency MT2019, trip 15251004-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:21:08, INFO: 	Routing agency MT2019, trip 15251735-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:21:23, INFO: 	Routing agency MT2019, trip 15245264-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:21:45, INFO: 	Routing agency MT2019, trip 15246053-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:22:05, INFO: 	Routing agency MT2019, trip 15249897-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:22:19, INFO: 	Routing agency MT2019, trip 15251361-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:22:38, INFO: 	Routing agency MT2019, trip 15287176-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:23:07, INFO: 	Routing agency MT2019, trip 15284936-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:23:30, INFO: 	Routing agency MT2019, trip 15246227-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:24:01, INFO: 	Routing agency MT2019, trip 15247750-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:24:26, INFO: 	Routing agency MT2019, trip 15251381-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:24:56, INFO: 	Routing agency MT2019, trip 15289937-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:25:09, INFO: 	Routing agency MT2019, trip 15251169-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:25:29, INFO: 	Routing agency MT2019, trip 15250630-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:25:58, INFO: 	Routing agency MT2019, trip 15415167-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:26:19, INFO: 	Routing agency MT2019, trip 15251349-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:26:40, INFO: 	Routing agency MT2019, trip 15284989-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:27:01, INFO: 	Routing agency MT2019, trip 15249888-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:27:14, INFO: 	Routing agency MT2019, trip 15245327-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:27:43, INFO: 	Routing agency MT2019, trip 15289974-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:27:58, INFO: 	Routing agency MT2019, trip 15250503-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:28:19, INFO: 	Routing agency MT2019, trip 15249069-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:28:43, INFO: 	Routing agency MT2019, trip 15246918-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:29:18, INFO: 	Routing agency MT2019, trip 15251724-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:29:34, INFO: 	Routing agency MT2019, trip 15251400-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:30:09, INFO: 	Routing agency MT2019, trip 15250260-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:30:36, INFO: 	Routing agency MT2019, trip 15415168-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:31:07, INFO: 	Routing agency MT2019, trip 15248566-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:31:37, INFO: 	Routing agency MT2019, trip 15249923-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:31:52, INFO: 	Routing agency MT2019, trip 15249912-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:32:05, INFO: 	Routing agency MT2019, trip 15244470-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:32:33, INFO: 	Routing agency MT2019, trip 15701426-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:33:04, INFO: 	Routing agency MT2019, trip 15249797-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:33:19, INFO: 	Routing agency MT2019, trip 15273471-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 21:33:48, INFO: 	Routing agency MT2019, trip 15247492-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:34:22, INFO: 	Routing agency MT2019, trip 15251573-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:34:32, INFO: 	Routing agency MT2019, trip 15288887-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:35:02, INFO: 	Routing agency MT2019, trip 15249910-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:35:16, INFO: 	Routing agency MT2019, trip 15250235-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:35:42, INFO: 	Routing agency MT2019, trip 15246104-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:36:09, INFO: 	Routing agency MT2019, trip 15245537-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:36:32, INFO: 	Routing agency MT2019, trip 15249743-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:36:46, INFO: 	Routing agency MT2019, trip 15249750-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:37:00, INFO: 	Routing agency MT2019, trip 15249732-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:37:13, INFO: 	Routing agency MT2019, trip 15251730-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:37:28, INFO: 	Routing agency MT2019, trip 15293730-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:37:56, INFO: 	Routing agency MT2019, trip 15250774-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:38:33, INFO: 	Routing agency MT2019, trip 15699613-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:38:57, INFO: 	Routing agency MT2019, trip 15289929-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:39:16, INFO: 	Routing agency MT2019, trip 15249333-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:39:33, INFO: 	Routing agency MT2019, trip 15249460-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:40:21, INFO: 	Routing agency MT2019, trip 15249753-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:40:36, INFO: 	Routing agency MT2019, trip 15249734-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:40:50, INFO: 	Routing agency MT2019, trip 15249740-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:41:04, INFO: 	Routing agency MT2019, trip 15245177-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:41:18, INFO: 	Routing agency MT2019, trip 15249371-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:41:35, INFO: 	Routing agency MT2019, trip 15249739-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:41:49, INFO: 	Routing agency MT2019, trip 15245557-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:42:24, INFO: 	Routing agency MT2019, trip 15288510-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:42:48, INFO: 	Routing agency MT2019, trip 15244828-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:43:09, INFO: 	Routing agency MT2019, trip 15251529-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:43:22, INFO: 	Routing agency MT2019, trip 15251568-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:43:31, INFO: 	Routing agency MT2019, trip 15245905-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:43:55, INFO: 	Routing agency MT2019, trip 15250772-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:44:22, INFO: 	Routing agency MT2019, trip 15251733-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:44:37, INFO: 	Routing agency MT2019, trip 15245632-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:44:56, INFO: 	Routing agency MT2019, trip 15245194-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:45:09, INFO: 	Routing agency MT2019, trip 15247997-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:45:31, INFO: 	Routing agency MT2019, trip 15285291-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:45:55, INFO: 	Routing agency MT2019, trip 15249677-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:46:24, INFO: 	Routing agency MT2019, trip 15251411-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:46:44, INFO: 	Routing agency MT2019, trip 15251771-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:46:55, INFO: 	Routing agency MT2019, trip 15245238-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:47:18, INFO: 	Routing agency MT2019, trip 15251755-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:47:43, INFO: 	Routing agency MT2019, trip 15249068-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:48:07, INFO: 	Routing agency MT2019, trip 15251509-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:48:20, INFO: 	Routing agency MT2019, trip 15249480-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:49:06, INFO: 	Routing agency MT2019, trip 15251767-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:49:17, INFO: 	Routing agency MT2019, trip 15245704-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:49:35, INFO: 	Routing agency MT2019, trip 15250986-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:50:16, INFO: 	Routing agency MT2019, trip 15250266-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:50:41, INFO: 	Routing agency MT2019, trip 15247507-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:51:15, INFO: 	Routing agency MT2019, trip 15249723-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:51:29, INFO: 	Routing agency MT2019, trip 15288945-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:51:58, INFO: 	Routing agency MT2019, trip 15249000-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:52:24, INFO: 	Routing agency MT2019, trip 15248027-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:52:47, INFO: 	Routing agency MT2019, trip 15273448-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 21:53:16, INFO: 	Routing agency MT2019, trip 15289275-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:53:34, INFO: 	Routing agency MT2019, trip 15250128-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:54:16, INFO: 	Routing agency MT2019, trip 15251455-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:54:37, INFO: 	Routing agency MT2019, trip 15245570-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:54:56, INFO: 	Routing agency MT2019, trip 15246645-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:55:14, INFO: 	Routing agency MT2019, trip 15250236-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:55:39, INFO: 	Routing agency MT2019, trip 15249001-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:56:05, INFO: 	Routing agency MT2019, trip 15288502-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:56:27, INFO: 	Routing agency MT2019, trip 15248879-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:56:46, INFO: 	Routing agency MT2019, trip 15246264-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:57:04, INFO: 	Routing agency MT2019, trip 15250916-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:57:41, INFO: 	Routing agency MT2019, trip 15246102-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:58:08, INFO: 	Routing agency MT2019, trip 15245145-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:58:19, INFO: 	Routing agency MT2019, trip 15248876-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:58:37, INFO: 	Routing agency MT2019, trip 15250314-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:58:56, INFO: 	Routing agency MT2019, trip 15246143-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:59:22, INFO: 	Routing agency MT2019, trip 15285292-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 21:59:46, INFO: 	Routing agency MT2019, trip 15249678-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:00:05, INFO: 	Routing agency MT2019, trip 15701417-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:00:49, INFO: 	Routing agency MT2019, trip 15251005-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:01:23, INFO: 	Routing agency MT2019, trip 15286138-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:01:42, INFO: 	Routing agency MT2019, trip 15247489-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:02:09, INFO: 	Routing agency MT2019, trip 15286075-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:02:28, INFO: 	Routing agency MT2019, trip 15286139-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:02:49, INFO: 	Routing agency MT2019, trip 15251448-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:03:02, INFO: 	Routing agency MT2019, trip 15756011-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:03:39, INFO: 	Routing agency MT2019, trip 15245231-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:04:03, INFO: 	Routing agency MT2019, trip 15273541-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:04:13, INFO: 	Routing agency MT2019, trip 15248877-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:04:31, INFO: 	Routing agency MT2019, trip 15250997-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:05:06, INFO: 	Routing agency MT2019, trip 15249386-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:05:24, INFO: 	Routing agency MT2019, trip 15249332-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:05:41, INFO: 	Routing agency MT2019, trip 15249708-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:06:04, INFO: 	Routing agency MT2019, trip 15289949-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:06:18, INFO: 	Routing agency MT2019, trip 15246245-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:06:31, INFO: 	Routing agency MT2019, trip 15273491-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:06:58, INFO: 	Routing agency MT2019, trip 15289978-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:07:12, INFO: 	Routing agency MT2019, trip 15285118-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:07:30, INFO: 	Routing agency MT2019, trip 15251433-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:07:44, INFO: 	Routing agency MT2019, trip 15701441-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:08:12, INFO: 	Routing agency MT2019, trip 15247501-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:08:24, INFO: 	Routing agency MT2019, trip 15701431-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:09:01, INFO: 	Routing agency MT2019, trip 15251761-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:09:24, INFO: 	Routing agency MT2019, trip 15285109-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:09:42, INFO: 	Routing agency MT2019, trip 15248427-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:09:53, INFO: 	Routing agency MT2019, trip 15251127-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:10:09, INFO: 	Routing agency MT2019, trip 15285122-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:10:27, INFO: 	Routing agency MT2019, trip 15246706-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:10:45, INFO: 	Routing agency MT2019, trip 15288531-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:11:10, INFO: 	Routing agency MT2019, trip 15251491-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:11:45, INFO: 	Routing agency MT2019, trip 15251289-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:12:03, INFO: 	Routing agency MT2019, trip 15244158-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:12:31, INFO: 	Routing agency MT2019, trip 15249462-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:13:09, INFO: 	Routing agency MT2019, trip 15251128-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:13:24, INFO: 	Routing agency MT2019, trip 15248434-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:13:35, INFO: 	Routing agency MT2019, trip 15246244-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:14:00, INFO: 	Routing agency MT2019, trip 15251321-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:14:19, INFO: 	Routing agency MT2019, trip 15246253-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:14:45, INFO: 	Routing agency MT2019, trip 15251498-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:15:19, INFO: 	Routing agency MT2019, trip 15249823-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:16:30, INFO: 	Routing agency MT2019, trip 15247747-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:16:48, INFO: 	Routing agency MT2019, trip 15249707-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:17:10, INFO: 	Routing agency MT2019, trip 15246092-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:17:34, INFO: 	Routing agency MT2019, trip 15250884-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:17:49, INFO: 	Routing agency MT2019, trip 15249832-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:18:47, INFO: 	Routing agency MT2019, trip 15273549-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:18:57, INFO: 	Routing agency MT2019, trip 15249464-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:19:43, INFO: 	Routing agency MT2019, trip 15245488-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:20:03, INFO: 	Routing agency MT2019, trip 15285497-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:20:21, INFO: 	Routing agency MT2019, trip 15250879-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:20:35, INFO: 	Routing agency MT2019, trip 15288521-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:20:58, INFO: 	Routing agency MT2019, trip 15246649-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:21:31, INFO: 	Routing agency MT2019, trip 15243970-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:21:54, INFO: 	Routing agency MT2019, trip 15251125-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:22:09, INFO: 	Routing agency MT2019, trip 15288525-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:22:30, INFO: 	Routing agency MT2019, trip 15243856-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:22:53, INFO: 	Routing agency MT2019, trip 15251131-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:23:07, INFO: 	Routing agency MT2019, trip 15246427-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:23:43, INFO: 	Routing agency MT2019, trip 15246327-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:24:10, INFO: 	Routing agency MT2019, trip 15250072-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:24:38, INFO: 	Routing agency MT2019, trip 15250080-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:25:06, INFO: 	Routing agency MT2019, trip 15246972-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:25:59, INFO: 	Routing agency MT2019, trip 15697732-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:26:22, INFO: 	Routing agency MT2019, trip 15251040-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:26:59, INFO: 	Routing agency MT2019, trip 15273473-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:27:28, INFO: 	Routing agency MT2019, trip 15701307-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:28:06, INFO: 	Routing agency MT2019, trip 15251403-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:28:36, INFO: 	Routing agency MT2019, trip 15273437-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:28:45, INFO: 	Routing agency MT2019, trip 15756090-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:29:42, INFO: 	Routing agency MT2019, trip 15699621-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:30:32, INFO: 	Routing agency MT2019, trip 15699647-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:31:14, INFO: 	Routing agency MT2019, trip 15273477-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:31:45, INFO: 	Routing agency MT2019, trip 15701308-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:32:21, INFO: 	Routing agency MT2019, trip 15250574-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:32:38, INFO: 	Routing agency MT2019, trip 15701313-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:33:15, INFO: 	Routing agency MT2019, trip 15701319-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:34:02, INFO: 	Routing agency MT2019, trip 15273558-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:34:29, INFO: 	Routing agency MT2019, trip 15756080-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:35:18, INFO: 	Routing agency MT2019, trip 15756078-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:36:08, INFO: 	Routing agency MT2019, trip 15251378-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:36:31, INFO: 	Routing agency MT2019, trip 15756088-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:37:31, INFO: 	Routing agency MT2019, trip 15246960-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:38:25, INFO: 	Routing agency MT2019, trip 15273527-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:38:49, INFO: 	Routing agency MT2019, trip 15248176-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:39:17, INFO: 	Routing agency MT2019, trip 15699629-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:39:58, INFO: 	Routing agency MT2019, trip 15249437-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:40:23, INFO: 	Routing agency MT2019, trip 15250972-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:40:55, INFO: 	Routing agency MT2019, trip 15246150-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:41:17, INFO: 	Routing agency MT2019, trip 15247989-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:41:32, INFO: 	Routing agency MT2019, trip 15273528-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:41:55, INFO: 	Routing agency MT2019, trip 15701317-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:42:31, INFO: 	Routing agency MT2019, trip 15250078-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:43:00, INFO: 	Routing agency MT2019, trip 15248859-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:43:20, INFO: 	Routing agency MT2019, trip 15251092-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:43:30, INFO: 	Routing agency MT2019, trip 15701399-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:44:34, INFO: 	Routing agency MT2019, trip 15288536-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:45:02, INFO: 	Routing agency MT2019, trip 15250962-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:45:23, INFO: 	Routing agency MT2019, trip 15246654-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:45:56, INFO: 	Routing agency MT2019, trip 15251044-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:46:20, INFO: 	Routing agency MT2019, trip 15245549-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:46:44, INFO: 	Routing agency MT2019, trip 15251459-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:47:21, INFO: 	Routing agency MT2019, trip 15248848-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:48:09, INFO: 	Routing agency MT2019, trip 15699237-AUG19-MVS-UM-Weekday-01
# 2022-03-11 22:48:25, INFO: 	Routing agency MT2019, trip 15250901-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:48:54, INFO: 	Routing agency MT2019, trip 15701398-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:49:49, INFO: 	Routing agency MT2019, trip 15250581-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:50:06, INFO: 	Routing agency MT2019, trip 15246176-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:50:28, INFO: 	Routing agency MT2019, trip 15250084-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:50:54, INFO: 	Routing agency MT2019, trip 15699668-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:51:49, INFO: 	Routing agency MT2019, trip 15286255-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:52:05, INFO: 	Routing agency MT2019, trip 15251720-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:52:17, INFO: 	Routing agency MT2019, trip 15756010-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:53:03, INFO: 	Routing agency MT2019, trip 15245547-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:53:29, INFO: 	Routing agency MT2019, trip 15246658-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:53:59, INFO: 	Routing agency MT2019, trip 15246651-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:54:43, INFO: 	Routing agency MT2019, trip 15244604-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:55:08, INFO: 	Routing agency MT2019, trip 15756101-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:55:47, INFO: 	Routing agency MT2019, trip 15756064-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:56:36, INFO: 	Routing agency MT2019, trip 15246152-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:56:58, INFO: 	Routing agency MT2019, trip 15251052-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:57:08, INFO: 	Routing agency MT2019, trip 15251023-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:57:49, INFO: 	Routing agency MT2019, trip 15756100-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:58:39, INFO: 	Routing agency MT2019, trip 15756076-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 22:59:24, INFO: 	Routing agency MT2019, trip 15697731-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 22:59:48, INFO: 	Routing agency MT2019, trip 15756015-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 23:00:23, INFO: 	Routing agency MT2019, trip 15699650-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:01:07, INFO: 	Routing agency MT2019, trip 15272782-AUG19-MVS-NS-Weekday-01-0000100
# 2022-03-11 23:02:14, INFO: 	Routing agency MT2019, trip 15272781-AUG19-MVS-NS-Weekday-01-0000100
# 2022-03-11 23:03:10, INFO: 	Routing agency MT2019, trip 15756151-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 23:03:55, INFO: 	Routing agency MT2019, trip 15249440-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:04:20, INFO: 	Routing agency MT2019, trip 15698451-AUG19-MVS-UM-Weekday-01
# 2022-03-11 23:04:53, INFO: 	Routing agency MT2019, trip 15244639-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:05:19, INFO: 	Routing agency MT2019, trip 15246534-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:05:47, INFO: 	Routing agency MT2019, trip 15699182-AUG19-MVS-UM-Weekday-01
# 2022-03-11 23:06:03, INFO: 	Routing agency MT2019, trip 15699065-AUG19-MVS-UM-Weekday-01
# 2022-03-11 23:06:19, INFO: 	Routing agency MT2019, trip 15251033-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:07:00, INFO: 	Routing agency MT2019, trip 15288937-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:07:24, INFO: 	Routing agency MT2019, trip 15246937-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:07:55, INFO: 	Routing agency MT2019, trip 15245988-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:08:41, INFO: 	Routing agency MT2019, trip 15698592-AUG19-MVS-UM-Weekday-01
# 2022-03-11 23:09:03, INFO: 	Routing agency MT2019, trip 15756055-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 23:09:54, INFO: 	Routing agency MT2019, trip 15288209-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:10:22, INFO: 	Routing agency MT2019, trip 15698396-AUG19-MVS-UM-Weekday-01
# 2022-03-11 23:10:37, INFO: 	Routing agency MT2019, trip 15288181-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:11:04, INFO: 	Routing agency MT2019, trip 15288944-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:11:27, INFO: 	Routing agency MT2019, trip 15246915-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:12:07, INFO: 	Routing agency MT2019, trip 15285192-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:12:41, INFO: 	Routing agency MT2019, trip 15250915-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:13:07, INFO: 	Routing agency MT2019, trip 15249223-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:13:35, INFO: 	Routing agency MT2019, trip 15273433-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 23:14:00, INFO: 	Routing agency MT2019, trip 15250129-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:14:32, INFO: 	Routing agency MT2019, trip 15250121-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:15:07, INFO: 	Routing agency MT2019, trip 15245969-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:15:52, INFO: 	Routing agency MT2019, trip 15273444-AUG19-MVS-SUB-Weekday-01
# 2022-03-11 23:16:03, INFO: 	Routing agency MT2019, trip 15272772-AUG19-MVS-NS-Weekday-01
# 2022-03-11 23:16:10, INFO: 	Routing agency MT2019, trip 15272783-AUG19-MVS-NS-Weekday-01
# 2022-03-11 23:16:17, INFO: 	Routing agency MT2019, trip 15251592-AUG19-MVS-BUS-Weekday-01
# 2022-03-11 23:16:32, INFO: 	Routing agency MV2019, trip 042-RL-446.1S-0711-20190518-Weekday-04
# 2022-03-11 23:16:59, INFO: 	Routing agency MV2019, trip 056-RA-446.0N-1003-20190518-Weekday-04
# 2022-03-11 23:17:25, INFO: 	Routing agency MV2019, trip 056-RA-446.0N-1003-20190914-Weekday-03
# 2022-03-11 23:17:53, INFO: 	Routing agency MV2019, trip 056-RA-446.0S-0909-20190518-Weekday-04
# 2022-03-11 23:18:20, INFO: 	Routing agency MV2019, trip 027-RL-446.0S-0609-20190914-Weekday-03
# 2022-03-11 23:18:48, INFO: 	Routing agency MV2019, trip 305-MA-440.0S-1148-20190518-Weekday-04
# 2022-03-11 23:19:11, INFO: 	Routing agency MV2019, trip 305-MA-440.0S-1148-20190914-Weekday-03
# 2022-03-11 23:19:25, INFO: 	Routing agency MV2019, trip 018-RL-444.1S-0936-20190518-Weekday-04
# 2022-03-11 23:19:45, INFO: 	Routing agency MV2019, trip 018-RL-444.1S-0936-20190914-Weekday-03
# 2022-03-11 23:20:04, INFO: 	Routing agency MV2019, trip 007-RL-444.1N-0731-20190914-Weekday-03
# 2022-03-11 23:20:24, INFO: 	Routing agency MV2019, trip 007-RL-444.1N-0731-20190518-Weekday-04
# 2022-03-11 23:20:44, INFO: 	Routing agency MV2019, trip 024-RL-440.2N-0729-20190914-Weekday-03
# 2022-03-11 23:21:08, INFO: 	Routing agency MV2019, trip 024-RL-440.2N-0729-20190518-Weekday-04
# 2022-03-11 23:21:31, INFO: 	Routing agency MV2019, trip 078-MA-440.0N-0831-20190914-Weekday-03
# 2022-03-11 23:21:45, INFO: 	Routing agency MV2019, trip 121-RL-484.0N-0632-20190518-Weekday-04
# 2022-03-11 23:22:22, INFO: 	Routing agency MV2019, trip 078-MA-440.0N-0831-20190518-Weekday-04
# 2022-03-11 23:22:35, INFO: 	Routing agency MV2019, trip 121-RL-484.0N-0632-20190914-Weekday-03
# 2022-03-11 23:23:22, INFO: 	Routing agency MV2019, trip 312-S1-442.1W-1249-20190914-Weekday-03
# ...
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_140042.matched.geojson
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_140045.matched.geojson
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_140062.matched.geojson
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_140063.matched.geojson
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_160001.matched.geojson
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_170019.matched.geojson
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_190002.matched.geojson
# 2022-03-13 22:31:27, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_190004.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_190006.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_20006.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_20008.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_20009.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_20010.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_210003.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_230001.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_230002.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_230003.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_230004.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_230008.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_2520001.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_270002.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_270003.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_300005.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_300006.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_300007.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_300008.matched.geojson
# 2022-03-13 22:31:28, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_30013.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_320002.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_320004.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6040001.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6040002.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6120001.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6120002.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6150001.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6150004.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_620013.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_620014.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_640014.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_640025.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6430003.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6520002.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_6520003.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_670003.matched.geojson
# 2022-03-13 22:31:29, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_680007.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_680008.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_700005.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_700008.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_710003.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_710006.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7160001.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7160002.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7220001.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7220004.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7220005.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7240001.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7410002.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_750002.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_750003.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_750005.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_750007.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_750011.matched.geojson
# 2022-03-13 22:31:30, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7580003.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7890001.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_7910001.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_800001.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_8010004.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_840001.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_840005.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_8600003.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_90002.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_9230001.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MT2019_9230002.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4200131.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4200134.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4200135.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4260046.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4420217.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4420219.matched.geojson
# 2022-03-13 22:31:31, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4420221.matched.geojson
# 2022-03-13 22:31:32, INFO: reading shst extraction data : D:/metcouncil_network_rebuild\data\external\gtfs\gtfs_shape_for_shst_match\match.lines_from_shapes_MV2019_4650406.matched.geojson
# 2022-03-13 22:31:32, INFO: ----------finished reading shst extraction data-------------
# 2022-03-13 22:31:35, INFO: representative trips include 578 bus shapes, 865 bus trips
# 2022-03-13 22:31:35, INFO: shst matched 48 bus shapes, 74 bus trips
# 2022-03-13 22:31:36, INFO: in the remaining gtfs shapes, shortest path method matched 530 bus shapes, 791 bus trips
# 2022-03-13 22:31:36, INFO: Updating stop node matching
# 2022-03-13 22:37:27, INFO: representative trips include 6 rail/ferry shapes, which are total of 10 trips
# C:\Users\wangs1\AppData\Local\Continuum\anaconda3\envs\ranch\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 2022-03-13 22:37:48, INFO: Creating frequency reference

# %%
# check if shortest path transit builder failed any transit shapes

transit_network.shortest_path_failed_shape_list
# Out:
# []

# %%
# writes out standard transit network and rail links/nodes if present

transit_network.write_standard_transit(
    path = interim_dir
)

# %%
# write out bus route for review
bus_trip_link_df = gpd.GeoDataFrame(
    transit_network.bus_trip_link_df, 
    crs = metc_roadway_network.links_df.crs)

bus_trip_link_df.drop('wayId', axis = 1).to_file(
    os.path.join(interim_dir, 'bus_routing.geojson'),
    driver = 'GeoJSON'
)

# %% [markdown]
# ## Step 7 - Build Centroid Connectors
#
# builds centroid connectors from TAZ

# %% [markdown]
# ### TAZ files

# %%
metc_taz_polygon_file = os.path.join(
    external_dir,
    'taz',
    'TAZ.shp'
)

metc_taz_centroid_file = os.path.join(
    external_dir,
    'taz',
    'TAZ_nodes.shp'
)

# %%
metc_taz_polygon_gdf = gpd.read_file(metc_taz_polygon_file)

metc_taz_centroid_gdf = gpd.read_file(metc_taz_centroid_file)

# %%
metc_taz_centroid_gdf['TAZ'] = metc_taz_centroid_gdf['N']
metc_taz_centroid_gdf['model_node_id'] = metc_taz_centroid_gdf['N']

# %%
metc_taz_centroid_gdf.to_file(
    os.path.join(
        external_dir,
        'taz',
        'TAZ_nodes.geojson'
    ),
    driver = 'GeoJSON'
)

# %%
metc_taz_polygon_gdf.head(2)
# Out:
#    OBJECTID  TAZ  POP2010  POPINHH10  PPH10  POPINGQ10  HH2010  EMP2010  \
# 0      3031    1     86.0       86.0   2.87        0.0    30.0      1.0
# 1      3032   10    225.0      225.0   3.46        0.0    65.0     10.0
#
#    NRET2010  RETAIL2010  ...  EMP2040  NRET2040  RETAIL2040  TCFLAG  \
# 0       1.0         0.0  ...      6.0       4.0         2.0     1.0
# 1      10.0         0.0  ...      8.0       8.0         0.0     1.0
#
#    ESOURCE10  ESOURCE14  ESOURCE18    Shape_STAr    Shape_STLe  \
# 0    LED2006   QCEW2014    LED2014  1.411847e+07  15327.348373
# 1   QCEW2010   QCEW2014   QCEW2017  2.539695e+06   6381.066223
#
#                                             geometry
# 0  POLYGON ((460555.993 5028987.573, 460851.077 5...
# 1  POLYGON ((479228.108 5025733.177, 479207.290 5...
#
# [2 rows x 57 columns]

# %%
print(metc_taz_polygon_gdf.TAZ.nunique())
print(metc_taz_polygon_gdf.TAZ.min())
print(metc_taz_polygon_gdf.TAZ.max())
# Out:
# 3030
# 1
# 3030

# %%
metc_taz_centroid_gdf.head(2)
# Out:
#    OBJECTID  N              X             Y                        geometry  \
# 0         1  1  462454.755934  5.027410e+06  POINT (462454.756 5027410.345)
# 1         2  2  468423.045357  5.028244e+06  POINT (468423.045 5028244.252)
#
#    TAZ  model_node_id
# 0    1              1
# 1    2              2

# %% [markdown]
# ### Build centroid connectors

# %%
metc_roadway_network.nodes_df.model_node_id.min()
# Out:
# 3101

# %%
metc_roadway_network.build_centroid_connectors(
    build_taz_drive = True,
    build_taz_active_modes = True,
    input_taz_polygon_file = metc_taz_polygon_file,
    input_taz_node_file= os.path.join(
        external_dir,
        'taz',
        'TAZ_nodes.geojson'
    ),
    taz_unique_id='TAZ'
)
# Out:
# 2022-03-17 10:22:29, INFO: input file D:/metcouncil_network_rebuild\data\external\taz\TAZ.shp has crs : epsg:26915
# 2022-03-17 10:22:30, INFO: input file D:/metcouncil_network_rebuild\data\external\taz\TAZ_nodes.geojson has crs : epsg:26915
# d:\github\ranch\ranch\roadway.py:1363: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: EPSG:4269
#
#   num_connectors_per_centroid,
# d:\github\ranch\ranch\roadway.py:1363: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: EPSG:4269
#
#   num_connectors_per_centroid,
# d:\github\ranch\ranch\roadway.py:1363: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: EPSG:4269
#
#   num_connectors_per_centroid,

# %%
metc_roadway_network.taz_cc_link_gdf.to_file(
    os.path.join(interim_dir, 'temp_centroid_connectors.geojson'),
    driver = 'GeoJSON'
)

# %%
# write out to pickle

metc_roadway_network.taz_node_gdf.to_pickle(
    os.path.join(interim_dir, 'centroid_node.pickle'),
)
metc_roadway_network.taz_cc_link_gdf.to_pickle(
    os.path.join(interim_dir, 'cc_link.pickle'),
)
metc_roadway_network.taz_cc_shape_gdf.to_pickle(
    os.path.join(interim_dir, 'cc_shape.pickle'),
)

# %%
metc_roadway_network.taz_cc_link_gdf
# Out:
#               A         B  drive_access  walk_access  bike_access  \
# 0      102455.0    1460.0             1            0            0
# 1      128772.0    1460.0             1            0            0
# 2      173207.0    1460.0             1            0            0
# 3       48855.0    1460.0             1            0            0
# 4      237105.0    1456.0             1            0            0
# ...         ...       ...           ...          ...          ...
# 47637     159.0    8026.0             0            1            1
# 47638    3017.0  322860.0             0            1            1
# 47639    3017.0  317675.0             0            1            1
# 47640    3017.0  305800.0             0            1            1
# 47641    3017.0  375165.0             0            1            1
#
#                          shstGeometryId                                id  \
# 0      be68d5105155224803a916f1b7673a60  be68d5105155224803a916f1b7673a60
# 1      bd96aa983487595e203ce16ab2a453a5  bd96aa983487595e203ce16ab2a453a5
# 2      a068b76ce96e7d6dc4b6a5856cda2d3a  a068b76ce96e7d6dc4b6a5856cda2d3a
# 3      65f5d3a0b2dad2527c7edb91ca8c2a7e  65f5d3a0b2dad2527c7edb91ca8c2a7e
# 4      a1cbb219075cfc246b24c986b1e5ef48  a1cbb219075cfc246b24c986b1e5ef48
# ...                                 ...                               ...
# 47637  a16bb0e4d23285b7e96814fa2c432681  a16bb0e4d23285b7e96814fa2c432681
# 47638  55e8eda676b507e1d010fbea7f162daf  55e8eda676b507e1d010fbea7f162daf
# 47639  5b1892bfdaa7029e127795fa53b936a9  5b1892bfdaa7029e127795fa53b936a9
# 47640  484279742712c53b3a856938bd8f320b  484279742712c53b3a856938bd8f320b
# 47641  7029be65d503fd849eb8cd4fddec0f03  7029be65d503fd849eb8cd4fddec0f03
#
#                   u            v                fromIntersectionId  \
# 0      9.800498e+08          NaN  e3809600ae9687b10115883a13a3bf4c
# 1      8.144914e+08          NaN  8b73508201be5b4e066bf0d3fcac1048
# 2      9.800498e+08          NaN  d02eb23520161ef8cb557f486f8380b9
# 3      9.800498e+08          NaN  bc537bb413b239b928fb22ddbc9ed524
# 4      1.093356e+09          NaN  4119faffac788aa9b7ac34b6a607fae2
# ...             ...          ...                               ...
# 47637           NaN  186246302.0                               NaN
# 47638           NaN  232012200.0                               NaN
# 47639           NaN  231970669.0                               NaN
# 47640           NaN  232046466.0                               NaN
# 47641           NaN  232177235.0                               NaN
#
#                        toIntersectionId    county roadway  \
# 0                                   NaN       NaN     taz
# 1                                   NaN       NaN     taz
# 2                                   NaN  Hennepin     taz
# 3                                   NaN  Hennepin     taz
# 4                                   NaN  Hennepin     taz
# ...                                 ...       ...     ...
# 47637  067555186f6c616b4ca9848f3c9ba712     Anoka     taz
# 47638  1f48d8eab7ccb91e8bc57a00a6ea5f62      Polk     taz
# 47639  4e4ec8af820728314fee78b279f1fdea      Polk     taz
# 47640  4a53b945986fb1eb0e16ca16c9d06cc5      Polk     taz
# 47641  d30d3e9278ad5e2a52685b9e14c182f7      Polk     taz
#
#                                                 geometry
# 0      LINESTRING (-93.28633 44.93045, -93.28632 44.9...
# 1      LINESTRING (-93.28504 44.93045, -93.28632 44.9...
# 2      LINESTRING (-93.28632 44.92864, -93.28632 44.9...
# 3      LINESTRING (-93.28632 44.93227, -93.28632 44.9...
# 4      LINESTRING (-93.28117 44.92323, -93.28118 44.9...
# ...                                                  ...
# 47637  LINESTRING (-93.07758 45.24171, -93.11184 45.2...
# 47638  LINESTRING (-92.34754 45.26688, -92.33156 45.2...
# 47639  LINESTRING (-92.31701 45.26949, -92.33156 45.2...
# 47640  LINESTRING (-92.29614 45.25259, -92.33156 45.2...
# 47641  LINESTRING (-92.37334 45.24337, -92.33156 45.2...
#
# [47642 rows x 14 columns]

# %%
metc_roadway_network.taz_node_gdf
# Out:
#       OBJECTID     N              X             Y  taz_id  model_node_id  \
# 0            1     1  462454.755934  5.027410e+06       1              1
# 1            2     2  468423.045357  5.028244e+06       2              2
# 2            3     3  466398.768445  5.026811e+06       3              3
# 3            4     4  469460.320755  5.026485e+06       4              4
# 4            5     5  470697.732820  5.026840e+06       5              5
# ...        ...   ...            ...           ...     ...            ...
# 3025      3026  3026  549229.165037  5.015010e+06    3026           3026
# 3026      3027  3027  550309.800325  5.015741e+06    3027           3027
# 3027      3028  3028  550659.781743  5.016609e+06    3028           3028
# 3028      3029  3029  537252.038875  5.020769e+06    3029           3029
# 3029      3030  3030  541989.561398  5.020658e+06    3030           3030
#
#                         geometry
# 0     POINT (-93.47971 45.39920)
# 1     POINT (-93.40351 45.40700)
# 2     POINT (-93.42928 45.39401)
# 3     POINT (-93.39015 45.39122)
# 4     POINT (-93.37436 45.39447)
# ...                          ...
# 3025  POINT (-92.37225 45.28687)
# 3026  POINT (-92.35839 45.29337)
# 3027  POINT (-92.35384 45.30115)
# 3028  POINT (-92.52453 45.33944)
# 3029  POINT (-92.46408 45.33818)
#
# [3030 rows x 7 columns]

# %% [markdown]
# ## Step 8 - Write out Standard Format

# %%
# this is the input county polygon file with county names

county_boundary_file = os.path.join(
    external_dir,
    "county", 
    "cb_2018_us_county_500k_withinMETC.geojson"
)

# specify the column to look for county name

county_variable_name = 'NAME'

metc_roadway_network.standard_format(
    county_boundary_file = county_boundary_file,
    county_variable_name = county_variable_name
)
# Out:
# 2022-03-18 10:49:39, INFO: Starting Step 8 creating roadway standard format

# %%
metc_roadway_network.links_df['rail_only'] = 0
metc_roadway_network.nodes_df['rail_only'] = 0

# %%
# save out the step 5 output as pickle file

working_network_filename = os.path.join(interim_dir,"step8_network.pickle")
pickle.dump(metc_roadway_network, open(working_network_filename, 'wb'))

# %%
RanchLogger.info("write out shape geojson")

shape_prop = ['id', 'fromIntersectionId', 'toIntersectionId', 'forwardReferenceId', 'backReferenceId']
shape_geojson = link_df_to_geojson(
    metc_roadway_network.shapes_df, 
    shape_prop
)

with open(os.path.join(interim_dir,"step8_shapes.geojson"), "w") as f:
    json.dump(shape_geojson, f)

RanchLogger.info("write out node geojson")

node_prop = metc_roadway_network.nodes_df.drop('geometry', axis = 1).columns.tolist()
node_geojson = point_df_to_geojson(
    metc_roadway_network.nodes_df, 
    node_prop
)

with open(os.path.join(interim_dir,"step8_nodes.geojson"), "w") as f:
    json.dump(node_geojson, f)

RanchLogger.info("write out link json")

link_prop = metc_roadway_network.links_df.drop(
    ['geometry'], 
    axis = 1
).columns.tolist()

out = metc_roadway_network.links_df[link_prop].to_json(orient = "records")

with open(os.path.join(interim_dir,"step8_links.json"), 'w') as f:
    f.write(out)
    
# the standard format for links are links.json, without the geometry
# here writing out links in links.geojson in case the user wants to visualize links

RanchLogger.info("write out link geojson")

link_prop = metc_roadway_network.links_df.drop('geometry', axis = 1).columns.tolist()
link_geojson = link_df_to_geojson(
    metc_roadway_network.links_df, 
    link_prop
)

with open(os.path.join(interim_dir,"step8_links.geojson"), "w") as f:
    json.dump(link_geojson, f)
# Out:
# 2022-03-18 10:52:38, INFO: write out shape geojson
# 2022-03-18 10:55:02, INFO: write out node geojson
# 2022-03-18 10:56:30, INFO: write out link json
# 2022-03-18 10:57:07, INFO: write out link geojson

# %%
print(metc_roadway_network.links_df.shape)
print(metc_roadway_network.links_df.model_link_id.nunique())
print(metc_roadway_network.links_df.shstReferenceId.nunique())
print(sum(metc_roadway_network.links_df.shstGeometryId.notnull()))
print(metc_roadway_network.links_df.shstGeometryId.nunique())
# Out:
# (1056575, 41)
# 1056575
# 1056575
# 1056575
# 553939

# %%
print(metc_roadway_network.shapes_df.shape)
print(metc_roadway_network.shapes_df.id.nunique())
# Out:
# (553939, 9)
# 553939

# %%
print(metc_roadway_network.nodes_df.shape)
print(metc_roadway_network.nodes_df.model_node_id.nunique())
print(len(set(metc_roadway_network.links_df.A.tolist() + metc_roadway_network.links_df.B.tolist())))
# Out:
# (412227, 9)
# 412227
# 412227

# %%
metc_roadway_network.links_df.rail_only.value_counts(dropna = False)
# Out:
# 0    1056575
# Name: rail_only, dtype: int64

# %%
metc_roadway_network.nodes_df.rail_only.value_counts(dropna = False)
# Out:
# 0    412227
# Name: rail_only, dtype: int64
