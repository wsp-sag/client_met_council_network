# %% [markdown]
# Model node and link IDs changed when rebuilding the base network from Ranch. By Conflating the old and new networks, we have a link ID crosswalk between the old link ID and new link ID.
#
# This notebook updates the IDs in project cards from old model IDs to new model IDs.

# %%
import os
import sys
import yaml
import pickle
import glob
import copy
import shutil

import pandas as pd

from network_wrangler import RoadwayNetwork
from network_wrangler import TransitNetwork
from network_wrangler import ProjectCard
from network_wrangler import Scenario
from network_wrangler import WranglerLogger

from lasso import Parameters

from network_wrangler.utils import create_unique_shape_id

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logger = logging.getLogger("WranglerLogger")
logger.handlers[0].stream = sys.stdout
logger.setLevel(logging.INFO)

# %% [markdown]
# # I/O

# %%
root_dir = "D:/metcouncil_network_rebuild"

old_network_project_card_folder_name = "ProjectCards"

new_network_project_card_folder_name = "ProjectCards_new_network"

old_project_cards_dir = os.path.join(root_dir, old_network_project_card_folder_name)
new_project_cards_dir = os.path.join(root_dir, new_network_project_card_folder_name)

# %%
# this notebook will copy the old project cards into the new project cards folder
# this notebook will directly overwrite the project cards

# check if the new folder exists
if os.path.isdir(new_project_cards_dir):
    print(f"Error: {new_project_cards_dir} exists! Please delete the existing folder.")
else:
    shutil.copytree(old_project_cards_dir, new_project_cards_dir)
    card_dir = new_project_cards_dir

# %%
lasso_dir = 'Z:/Data/Users/Sijia/Met_Council/github/client_met_council_wrangler_utilities'

# %%
parameters = Parameters(lasso_base_dir = lasso_dir)
# Out:
# 2023-05-30 16:10:20, INFO: Lasso base directory set as: Z:/Data/Users/Sijia/Met_Council/github/client_met_council_wrangler_utilities
# 2023-05-30 16:10:20, INFO: Lasso base directory set as: Z:/Data/Users/Sijia/Met_Council/github/client_met_council_wrangler_utilities

# %%
# link id crosswalk file
crosswalk_file = os.path.join(root_dir, 'data', 'interim', 'model_network_id_crosswalk_step2_augmented.csv')

# %% [markdown]
# # Process

# %%
# read crosswalk

crosswalk_df = pd.read_csv(crosswalk_file)

# %%
# There are links in the old network that did not get match to the new network
# drop those links

crosswalk_df = crosswalk_df[crosswalk_df['model_link_id_new'].notnull()].copy()

# %%
# convert link id to int

crosswalk_df['model_link_id_new'] = crosswalk_df['model_link_id_new'].astype(int)

# %%
# create dictionary of old_id: [new_id_1, new_id_2,...]
# as there might be one-to-many, many-to-many matches

link_crosswalk = crosswalk_df.groupby(['model_link_id_old'])['model_link_id_new'].apply(list).reset_index()

link_crosswalk = dict(zip(link_crosswalk['model_link_id_old'], link_crosswalk['model_link_id_new']))

# %%
link_crosswalk
# Out:
# {1: [409420],
#  3: [208243, 400359],
#  4: [343056, 282309],
#  6: [90253],
#  7: [771172],
#  8: [321093],
#  9: [169687],
#  12: [318570],
#  13: [115644],
#  14: [410498],
#  18: [943181],
#  19: [101107, 6733],
#  20: [431453],
#  22: [236240],
#  23: [795383, 806949],
#  24: [264002],
#  26: [60108, 371141],
#  27: [161715],
#  28: [91509],
#  29: [363994, 411025, 225533, 68168],
#  30: [13626, 22626],
#  31: [294239],
#  32: [425469, 144409, 533327],
#  33: [109665, 53465, 112902],
#  34: [520562, 435266, 519095, 107600, 434610],
#  35: [59698],
#  36: [56906, 313618],
#  37: [458138],
#  38: [247868, 327341],
#  39: [543978],
#  40: [362872],
#  41: [912396],
#  42: [413793],
#  43: [196420, 531270, 101137, 303830, 225306, 255161],
#  44: [13561, 81857],
#  45: [314642, 541995, 451583, 405177],
#  46: [536301],
#  47: [175556],
#  48: [277118, 115190],
#  49: [349043],
#  50: [115809],
#  51: [69529],
#  52: [772671, 905580, 924557, 845581, 862004, 945340],
#  53: [170357, 194705],
#  55: [270359],
#  56: [630577],
#  57: [477531, 430658, 438941],
#  58: [482574],
#  59: [383961],
#  60: [660292, 1009977, 731902, 788887, 566214, 874623, 899514, 730580],
#  61: [908358],
#  63: [301467, 348253, 94238],
#  64: [147880],
#  66: [28301],
#  67: [1005348],
#  68: [384845],
#  69: [688622],
#  70: [1027239],
#  71: [676607],
#  72: [31617],
#  73: [444139],
#  74: [575176],
#  75: [93291],
#  76: [7286],
#  77: [704390],
#  78: [182619],
#  79: [650558],
#  82: [937127],
#  83: [504352],
#  84: [462155, 27498],
#  85: [315377],
#  86: [958588, 969304, 758472, 982969, 655675],
#  87: [332515, 28400],
#  93: [523532],
#  94: [848608],
#  102: [431150],
#  103: [571602],
#  109: [146621],
#  111: [504399],
#  112: [973550, 819007],
#  114: [36197, 392077, 487328, 130981],
#  115: [428535],
#  118: [989303, 694480, 933717, 689944, 989303, 694480, 933717, 689944],
#  121: [366563],
#  122: [988303],
#  123: [778011, 406972],
#  125: [237667],
#  126: [423914],
#  127: [141340],
#  128: [862144],
#  130: [937636],
#  131: [27957],
#  132: [432776, 153088],
#  133: [925018],
#  134: [87522],
#  135: [443068],
#  136: [306304],
#  137: [800137],
#  138: [267956],
#  139: [915801],
#  140: [364180],
#  141: [72685],
#  142: [807157],
#  143: [391147, 300465],
#  145: [783813, 989765, 911655],
#  146: [161435, 225747],
#  147: [253269],
#  148: [1014045],
#  151: [255787, 255787],
#  153: [539377],
#  154: [183980],
#  156: [210789],
#  157: [533185, 109517],
#  160: [246856],
#  161: [707275],
#  162: [366193],
#  163: [860670],
#  164: [666324],
#  165: [22780],
#  166: [215578],
#  167: [1044894],
#  168: [240033],
#  169: [1054794],
#  170: [439131],
#  171: [957638],
#  172: [638416],
#  173: [527645],
#  174: [718190],
#  175: [443338],
#  176: [356955],
#  177: [936599],
#  178: [220080, 8955, 116692],
#  179: [496999, 976518],
#  180: [344437, 983118],
#  181: [547619, 627029],
#  182: [82465],
#  183: [1001411, 832785],
#  184: [667210, 567501],
#  187: [944451],
#  188: [422459, 232725],
#  189: [380952, 268338, 277323, 243487, 493073, 30372, 209397, 269288],
#  190: [1032833],
#  191: [402719, 601803],
#  192: [344437, 983118],
#  193: [370363, 654199],
#  194: [400042, 728101],
#  195: [20296],
#  196: [987214, 841049],
#  197: [89810],
#  198: [827498],
#  203: [496999, 976518],
#  204: [400042, 728101],
#  206: [1049834],
#  207: [2916, 2916],
#  211: [468632],
#  212: [623572],
#  219: [488907],
#  221: [660940],
#  222: [110735],
#  225: [372338],
#  226: [800625],
#  227: [518757],
#  229: [932921],
#  231: [487546, 430985, 425527, 16680, 478325, 199839, 546035, 199610, 503407],
#  232: [593614, 714553, 859986, 803315, 716590, 949424, 791908, 651869],
#  233: [814878, 690189, 682447],
#  235: [938527],
#  236: [236791],
#  237: [275087, 261768],
#  238: [127506],
#  239: [402719, 601803],
#  240: [529513, 710075],
#  241: [241790, 172198],
#  242: [547619, 627029],
#  243: [224998],
#  245: [11708],
#  246: [61036],
#  247: [539367],
#  248: [55481],
#  249: [490523, 274898, 331327],
#  250: [125781, 493447, 80808],
#  252: [376855],
#  253: [379060],
#  256: [535003, 120093],
#  258: [975609],
#  260: [825795, 876317],
#  261: [411348, 7403],
#  262: [591591, 850608],
#  264: [146898],
#  265: [907311, 1034345],
#  266: [162595],
#  267: [225220],
#  268: [589831, 776930, 1046841, 1013500],
#  270: [415566],
#  271: [454196, 208600],
#  274: [813110],
#  276: [740732],
#  277: [684574],
#  278: [269366],
#  280: [900977, 740538, 683585],
#  281: [144717],
#  282: [14557, 50952, 16439],
#  283: [482296],
#  284: [162865, 450927, 434252],
#  285: [692125, 741451, 874490],
#  289: [705469, 923691],
#  290: [176168, 32974],
#  291: [764051],
#  292: [486289, 327333, 396831],
#  293: [883148, 814577],
#  294: [206585],
#  295: [15974],
#  300: [954151, 801308],
#  301: [304950],
#  302: [831467, 864809, 668712],
#  303: [409599, 346357],
#  304: [305620],
#  305: [89143, 44652],
#  306: [986020],
#  309: [516114],
#  310: [782700],
#  312: [625605, 1050358, 913728],
#  313: [230261],
#  315: [895521],
#  316: [366310],
#  317: [905926, 578716, 555260, 998315, 932775, 641601, 900891, 662591, 556301],
#  327: [160955, 283293],
#  328: [755347],
#  329: [247466, 76225, 499374, 487707],
#  331: [737407],
#  334: [828338],
#  335: [853597, 917122, 804240, 989954],
#  336: [76429],
#  337: [481420, 32162],
#  338: [211489],
#  339: [402300],
#  340: [488194],
#  341: [191892],
#  342: [407267],
#  343: [267065, 225548, 462812, 383275],
#  344: [213947, 133165],
#  345: [329933],
#  346: [78049],
#  347: [374732],
#  348: [470669],
#  349: [104336],
#  350: [195399],
#  351: [15283, 47149, 99665],
#  352: [390084],
#  353: [356456],
#  354: [25929],
#  355: [453800],
#  356: [323433],
#  357: [491647],
#  358: [544293],
#  359: [478209],
#  361: [604992],
#  362: [513731],
#  365: [298026, 442109],
#  366: [909899],
#  367: [343564, 111593],
#  368: [23162, 7695],
#  369: [737667, 866818],
#  370: [440310],
#  371: [3856],
#  372: [98554],
#  373: [669700, 854849, 1046822],
#  382: [410767],
#  383: [580877],
#  392: [357996],
#  393: [766723],
#  397: [437114],
#  398: [871470],
#  401: [545687],
#  402: [811085],
#  404: [126564, 32828],
#  405: [783461, 752401],
#  407: [212333],
#  408: [290996],
#  409: [669368],
#  412: [1053715],
#  414: [634374],
#  416: [699501],
#  417: [495022],
#  418: [636920],
#  420: [447171, 507716],
#  421: [215122],
#  423: [120789],
#  424: [453157],
#  425: [676912],
#  426: [321454],
#  427: [770142],
#  428: [444721],
#  429: [987387],
#  430: [208847],
#  431: [160361],
#  432: [446619],
#  433: [398231, 270082],
#  434: [473206],
#  435: [153835, 21602],
#  436: [674896, 1010865],
#  440: [110866],
#  441: [617261],
#  443: [156920],
#  444: [953708, 753027],
#  446: [137780],
#  447: [678724, 914804],
#  448: [215803, 87130],
#  449: [39563, 412544],
#  450: [925993, 815723, 814004],
#  451: [539470, 91776],
#  453: [452611],
#  455: [348752],
#  456: [104855],
#  458: [1970, 707587],
#  459: [23786, 961384],
#  460: [850383],
#  461: [367566, 63540],
#  462: [744521, 765307, 655488],
#  464: [21808],
#  465: [921328],
#  466: [148900],
#  469: [207575, 732020],
#  470: [382685, 628589],
#  472: [526436],
#  473: [715094, 1017202],
#  475: [1000114],
#  476: [527351, 192674, 403596, 252817, 80842, 418658, 764325, 481685],
#  477: [686079, 580277, 1006814],
#  482: [962128],
#  483: [495117],
#  487: [226792, 409636, 162217, 298299],
#  488: [872606],
#  494: [544413],
#  496: [1053151],
#  497: [80200],
#  498: [33588],
#  499: [560006],
#  501: [933422],
#  504: [191474, 708960],
#  505: [65656, 671554],
#  506: [297044],
#  507: [972131],
#  508: [456453],
#  510: [328533],
#  512: [991735],
#  513: [59358],
#  514: [450501],
#  515: [1042668],
#  518: [339287],
#  519: [533242],
#  520: [1042416],
#  521: [953440],
#  522: [17351],
#  523: [902958],
#  525: [264993],
#  526: [883061],
#  527: [586752],
#  528: [516335],
#  529: [761161, 1052305],
#  530: [965914],
#  531: [933922],
#  532: [350009, 470922],
#  533: [975307],
#  537: [140356, 243530, 66277],
#  538: [881381, 963696],
#  540: [865847],
#  541: [516785, 912255],
#  542: [665516, 605803],
#  544: [99346, 280390],
#  545: [108798],
#  546: [887314, 622604],
#  547: [985140],
#  548: [334931, 298669],
#  550: [871149],
#  551: [526867, 398775],
#  552: [887169],
#  553: [438916],
#  554: [653520, 630580],
#  555: [328468, 106341],
#  556: [398852, 854449],
#  558: [586848],
#  559: [1034563, 1008663],
#  560: [58980],
#  562: [932296],
#  564: [83564, 153801],
#  565: [184345],
#  566: [48542],
#  567: [754182],
#  570: [208266, 171468],
#  571: [1005581, 735403],
#  572: [893139],
#  573: [485742],
#  574: [206185],
#  577: [301540],
#  578: [852811, 929367],
#  579: [12762],
#  580: [498696],
#  581: [826380],
#  582: [1026060],
#  583: [698181],
#  584: [51004],
#  585: [952428],
#  586: [874052],
#  587: [14153],
#  588: [886542, 820859],
#  590: [378113],
#  591: [115274],
#  592: [1003913, 1022800],
#  593: [669275, 582485],
#  594: [349592],
#  595: [829591],
#  598: [383415],
#  599: [668076],
#  600: [369595],
#  601: [143010],
#  602: [954346],
#  603: [719171],
#  604: [873830],
#  606: [85555],
#  607: [596771, 914238],
#  608: [91652, 204516],
#  609: [838838],
#  610: [157827],
#  612: [427622],
#  614: [249723],
#  615: [702244],
#  617: [343133],
#  618: [583266],
#  619: [441850],
#  620: [851228],
#  621: [389087, 218530],
#  622: [39037],
#  623: [1054953],
#  624: [848126],
#  625: [525068],
#  626: [788041],
#  627: [835895, 841671],
#  628: [496840],
#  629: [968248, 626610],
#  630: [660988, 1013988, 966242],
#  631: [295965, 437655, 343276],
#  632: [896714],
#  633: [212686],
#  634: [327738, 518948, 471692],
#  635: [340645],
#  636: [816144, 749439],
#  637: [528289],
#  639: [581221],
#  641: [41728],
#  642: [66402, 841694],
#  643: [35664, 903518],
#  647: [1391],
#  649: [431335, 508610],
#  652: [175187],
#  653: [855086],
#  656: [43051],
#  657: [625190],
#  658: [190308],
#  659: [199725],
#  660: [656042],
#  661: [178930],
#  662: [560007],
#  664: [326648, 26828],
#  665: [649783],
#  666: [250854],
#  667: [279960, 100047],
#  669: [544246],
#  670: [317647],
#  671: [907965],
#  672: [4736],
#  673: [752796],
#  675: [583333],
#  676: [330619],
#  678: [773842],
#  679: [257311, 406425],
#  680: [646896],
#  681: [815994, 218655, 524356],
#  682: [139615],
#  686: [558906],
#  687: [128892],
#  688: [723982],
#  689: [458549],
#  691: [335194, 522741, 96231],
#  693: [27012, 431456, 278588],
#  694: [632256],
#  696: [513392, 994136, 734870],
#  697: [232158],
#  699: [460329],
#  700: [989562],
#  701: [576095, 559117, 561519, 930320, 913978, 680893, 580609, 888387, 581376],
#  702: [284373, 318954, 453952],
#  703: [269512, 509492, 13875, 285659, 288418],
#  706: [256751],
#  708: [795063],
#  709: [388777],
#  710: [1000572,
#   1016577,
#   941031,
#   569356,
#   845528,
#   656309,
#   597741,
#   945225,
#   763471],
#  712: [616899],
#  713: [502060],
#  714: [109366],
#  715: [132107, 494144],
#  716: [185111, 837434],
#  717: [185111, 837434],
#  719: [154853],
#  720: [741142],
#  721: [185111, 837434],
#  722: [185111],
#  723: [238878],
#  724: [935080],
#  726: [151818],
#  727: [220012],
#  728: [746946],
#  729: [222703, 581963],
#  730: [222703, 581963],
#  731: [359056],
#  732: [482250],
#  733: [862522],
#  734: [339024],
#  735: [891855],
#  736: [177731],
#  737: [878249],
#  738: [514389],
#  739: [69520],
#  740: [657374],
#  741: [210212, 84802],
#  743: [290050],
#  744: [1013792,
#   919728,
#   838986,
#   639246,
#   972699,
#   872610,
#   1016481,
#   168784,
#   820857],
#  747: [269875],
#  748: [183249],
#  749: [595992],
#  751: [335656, 278973],
#  752: [628308],
#  754: [131936],
#  755: [311538],
#  756: [731925],
#  757: [194800],
#  758: [379862],
#  759: [298298, 413998],
#  760: [390380],
#  761: [264478],
#  762: [648495],
#  764: [426071],
#  765: [847486],
#  766: [118207],
#  767: [85699],
#  768: [373971],
#  769: [152914, 490588],
#  770: [917339],
#  771: [537628, 117282],
#  772: [54557],
#  774: [899668],
#  775: [187373],
#  776: [96279],
#  778: [509043],
#  779: [627955],
#  781: [929122],
#  782: [265408],
#  783: [554679],
#  790: [1047095, 942331, 726665, 1030340],
#  791: [936462],
#  795: [995351, 1016791],
#  796: [812446],
#  797: [142680],
#  798: [204663, 957096],
#  799: [610446],
#  808: [538407],
#  809: [731062, 783095],
#  816: [1723],
#  817: [903507],
#  818: [756884],
#  824: [58552, 488535],
#  826: [805761],
#  827: [179408, 468595],
#  828: [460126],
#  829: [39574, 764889],
#  830: [299216],
#  832: [545451],
#  834: [409325],
#  835: [484470, 283271],
#  839: [361569],
#  840: [300877],
#  841: [244784, 249168],
#  842: [982624],
#  843: [207102],
#  844: [33420],
#  846: [715555],
#  847: [304758],
#  849: [64496],
#  850: [946340],
#  857: [1048027],
#  858: [456791],
#  859: [433584, 512904, 141492, 473498],
#  863: [602025],
#  864: [422154, 176777],
#  865: [563636],
#  866: [128623],
#  867: [987556],
#  868: [470890],
#  869: [498860, 276315, 916178],
#  870: [609020],
#  872: [564205],
#  873: [394136, 418442, 1874, 71215],
#  874: [175949],
#  875: [400046, 362667],
#  876: [230320, 191178],
#  877: [239551, 374797, 333827],
#  878: [210713, 404342],
#  879: [699507],
#  880: [201190],
#  881: [94432],
#  882: [441463],
#  883: [926169, 578091],
#  884: [515863, 454863, 56347],
#  885: [519597, 289408],
#  886: [780167],
#  887: [247888],
#  888: [1020388, 1023215],
#  889: [307531, 540258, 102918],
#  890: [536520, 300561],
#  891: [848721],
#  892: [295260],
#  893: [35985, 213551],
#  894: [763410, 117038],
#  896: [527124, 296264],
#  897: [684881, 994536, 640964],
#  898: [115258],
#  899: [165811],
#  900: [836992],
#  901: [214116],
#  902: [286280],
#  903: [953191],
#  904: [877858],
#  905: [330893],
#  906: [746167],
#  907: [253743, 295861],
#  916: [266309, 572249],
#  918: [359033],
#  921: [156326, 940229],
#  922: [951814],
#  923: [352583],
#  927: [458739, 417053],
#  928: [844340],
#  929: [267214],
#  936: [57849],
#  937: [831937],
#  939: [517258, 204070],
#  940: [995371],
#  941: [799082],
#  943: [603139],
#  944: [172368],
#  945: [130961],
#  946: [715921],
#  947: [653091],
#  948: [412209],
#  949: [212228, 99937],
#  950: [857610],
#  951: [101080, 241817],
#  952: [61589],
#  953: [782550, 727460],
#  956: [402192],
#  957: [855999],
#  959: [383033],
#  960: [73389],
#  961: [880457],
#  962: [479810],
#  963: [806834],
#  964: [951322],
#  966: [120654],
#  967: [830258],
#  968: [201730],
#  969: [613587],
#  970: [323539],
#  971: [672332],
#  972: [526840],
#  973: [763516, 846747],
#  974: [386218],
#  975: [940889],
#  978: [978088],
#  980: [232416],
#  981: [961895],
#  985: [94881],
#  986: [728914],
#  988: [175523, 118075],
#  989: [879917],
#  990: [214436],
#  992: [593005],
#  994: [893276],
#  995: [529870],
#  996: [238603],
#  997: [583964],
#  1002: [498861],
#  1003: [601788],
#  1004: [506761],
#  1009: [78546],
#  1010: [763382],
#  1012: [45764],
#  1013: [869525],
#  1014: [571959],
#  1015: [435713],
#  1016: [124290],
#  1017: [932860],
#  1018: [507618],
#  1019: [851417],
#  1020: [607863, 1042975],
#  1022: [658790],
#  1024: [412142],
#  1025: [896934],
#  1026: [963508],
#  1027: [16632, 127423],
#  1028: [896681, 1045367, 995914, 911092, 710691, 792328, 619626],
#  1029: [113564],
#  1031: [386394],
#  1032: [363056],
#  1033: [1042975],
#  1034: [185863],
#  1035: [675981],
#  1036: [514912],
#  1038: [679751],
#  1039: [701691],
#  1041: [113031],
#  1043: [483648],
#  1044: [32665, 309649],
#  1045: [655457],
#  1046: [273921],
#  1047: [456201],
#  1048: [650440],
#  1049: [57028],
#  1050: [362445],
#  1051: [829108],
#  1052: [124676],
#  1053: [910],
#  1055: [335088],
#  1056: [98775],
#  1057: [119462],
#  1058: [475307],
#  1059: [729281],
#  1060: [67333],
#  1061: [333460],
#  1062: [394809],
#  1063: [8176],
#  1067: [930906],
#  1068: [775104],
#  1074: [191450],
#  1075: [637299],
#  1076: [575748, 553167],
#  1077: [256840],
#  1078: [73534],
#  1080: [828398, 646696, 951694],
#  1081: [360606],
#  1082: [14359, 948730],
#  1083: [56651, 173285, 130486, 306687],
#  1084: [413197],
#  1086: [672269],
#  1087: [473459],
#  1089: [942378],
#  1090: [107048],
#  1091: [940599],
#  1092: [248746],
#  1093: [769045],
#  1094: [88675],
#  1096: [121021],
#  1097: [897400],
#  1099: [659926],
#  1100: [425929, 491352],
#  1102: [101014],
#  1103: [462192],
#  1104: [603729],
#  1105: [287122],
#  1106: [221609],
#  1107: [460629],
#  1108: [618167],
#  1109: [413581],
#  1110: [325560],
#  1111: [382549],
#  1112: [265069],
#  1113: [345976],
#  1114: [878198, 283512],
#  1116: [46451],
#  1117: [145950, 524822],
#  1118: [279196],
#  1119: [460147],
#  1120: [177705],
#  1121: [319586],
#  1122: [460906],
#  1123: [529435],
#  1124: [540470],
#  1125: [362237, 99820],
#  1126: [186397, 510009],
#  1127: [677706],
#  1129: [769456],
#  1130: [279941, 163225, 322868],
#  1131: [284149, 36012],
#  1133: [288544],
#  1134: [598528, 791217],
#  1135: [29206, 476370],
#  1136: [640425, 691908],
#  1137: [503957],
#  1138: [194796, 250030],
#  1139: [976717],
#  1140: [357907],
#  1141: [787323, 559156],
#  1142: [261757],
#  1143: [482737, 259016],
#  1144: [307299, 235151],
#  1145: [458931],
#  1146: [1037388],
#  1147: [243915],
#  1148: [739042],
#  1149: [523430],
#  1153: [378010],
#  1154: [285064],
#  1155: [337857, 549670, 232155],
#  1156: [50156],
#  1158: [239048, 523491, 328909, 425799, 50818],
#  1159: [863755, 596948, 818052, 1015754, 579809],
#  1162: [250838],
#  1163: [67123, 307827],
#  1164: [607466, 904058],
#  1165: [543723, 66364, 302839],
#  1166: [1021735],
#  1167: [461953],
#  1168: [821371, 669580],
#  1169: [483258, 441584],
#  1170: [112571],
#  1171: [580456],
#  1172: [340473],
#  1173: [287824],
#  1174: [24283, 306203],
#  1175: [802590, 657931, 698947],
#  1176: [662629],
#  1177: [246756, 547607],
#  1178: [87316, 351247],
#  1179: [233515, 497919],
#  1180: [718014, 925608],
#  1181: [186924],
#  1182: [534483],
#  1183: [678471, 821229, 683101],
#  1184: [472684],
#  1185: [672141],
#  1186: [220348, 474657],
#  1187: [227580],
#  1188: [790637],
#  1189: [490735],
#  1190: [167104],
#  1191: [1043330],
#  1192: [190546],
#  1193: [500368],
#  1194: [594388],
#  1195: [40760],
#  1197: [1046735],
#  1198: [501657, 219463, 291415],
#  1202: [1057815],
#  1203: [1060332, 1060333, 1060322, 1060324],
#  1204: [1057817],
#  1206: [296610],
#  1207: [398306],
#  1208: [720721],
#  1211: [613396, 727147],
#  1212: [130140],
#  1213: [550472],
#  1214: [1017491],
#  1216: [821287],
#  1217: [437531, 4363],
#  1218: [141925],
#  1219: [149487],
#  1221: [407145],
#  1222: [624829],
#  1223: [474476, 361960],
#  1224: [1004986],
#  1225: [235169],
#  1226: [41550, 348116],
#  1227: [229912, 120341],
#  1228: [616026],
#  1229: [544965, 387794, 390527],
#  1230: [298831],
#  1231: [363943],
#  1232: [535637, 205750],
#  1233: [198856],
#  1234: [585735],
#  1235: [551913, 345558],
#  1237: [491659],
#  1238: [1048793],
#  1239: [322675, 811722],
#  1240: [769650],
#  1241: [135048, 513152],
#  1242: [145475],
#  1243: [740242],
#  1244: [403313],
#  1245: [293985, 150349],
#  1246: [742618],
#  1247: [235908],
#  1248: [543419, 168043],
#  1249: [941543],
#  1250: [36471, 240447],
#  1251: [390274],
#  1252: [795190],
#  1253: [110207],
#  1254: [325189, 423988],
#  1255: [670706],
#  1256: [65800],
#  1257: [218642],
#  1258: [512459],
#  1259: [998596],
#  1260: [193526],
#  1261: [70515],
#  1262: [937151],
#  1263: [367915],
#  1264: [162873],
#  1265: [603101],
#  1269: [235333, 768615],
#  1270: [322675, 811722],
#  1271: [56482, 582076],
#  1272: [648458],
#  1273: [981301],
#  1274: [132753],
#  1277: [784779, 696879, 660351, 872735],
#  1278: [467745],
#  1279: [1026515],
#  1280: [1049772],
#  1281: [184706, 1048793],
#  1282: [184706],
#  1283: [498183],
#  1284: [1032391],
#  1285: [400425],
#  1287: [492846],
#  1288: [1050581],
#  1289: [260974, 736793],
#  1290: [276223],
#  1291: [975519],
#  1295: [339942],
#  1296: [964047, 695960],
#  1300: [327141],
#  1301: [725779],
#  1302: [886683],
#  1304: [184706, 1048793],
#  1305: [260974, 736793],
#  1306: [18537],
#  1308: [642534],
#  1309: [173500, 259360],
#  1310: [80839],
#  1311: [750413],
#  1312: [879465, 795332],
#  1313: [228278, 100314, 272917, 20237, 337306, 197777],
#  1314: [164065],
#  1315: [125322, 197451, 434773],
#  1316: [249205],
#  1317: [76367, 115139],
#  1318: [105766],
#  1322: [1012384],
#  1323: [337693, 211455, 399274],
#  1324: [548452, 492587],
#  1325: [921142],
#  1328: [309534, 4765],
#  1329: [694552],
#  1330: [396689],
#  1331: [152591],
#  1332: [87595],
#  1333: [562943],
#  1336: [68085, 891043],
#  1337: [661875],
#  1338: [252501],
#  1339: [486166],
#  1340: [661878],
#  1341: [215627],
#  1342: [945606],
#  1343: [86696, 477120],
#  1346: [531248],
#  1347: [415789],
#  1348: [367634],
#  1349: [469769, 476687],
#  1350: [434775],
#  1351: [485312, 123181, 48043],
#  1352: [866481],
#  1353: [588588],
#  1354: [623244],
#  1355: [354656, 950947],
#  1357: [278012],
#  1358: [1053016],
#  1359: [110347, 510276],
#  1360: [220145],
#  1361: [577107],
#  1362: [38581, 274640],
#  1363: [304603],
#  1364: [897222],
#  1365: [946897],
#  1367: [421035],
#  1368: [836752],
#  1373: [827465],
#  1374: [391593],
#  1375: [1017761],
#  1376: [98033],
#  1377: [335506],
#  1379: [476435],
#  1380: [721548],
#  1381: [448391],
#  1382: [634005],
#  1383: [403012],
#  1385: [995454, 778026],
#  1386: [660931],
#  1387: [17287],
#  ...}

# %% [markdown]
# # Update project cards with new IDs

# %%
# get a list of project card files

suffix = ["*.yaml", "*.yml"] #"*.wrangler", "*.wr"
card_list = []
for s in suffix:
    card_list.extend(glob.glob(os.path.join(card_dir, "**", s), recursive=True))

# %%
# print # project cards

print(str(len(card_list)) + " project cards")
# Out:
# 101 project cards

# %%
import re

# %%
# define functions

def map_new_id(x, crosswalk):
    """
    return value from crosswalk
    """
    return crosswalk.get(x)

def transit_id_change(d, links_missing_correspondence_list):
    """
    update model node id in transit routing project cards
    """
    for p in d.get('properties'):
        if p.get('property') == 'routing':
            _existing = []
            _set = []
            for n in p.get('existing'):
                if abs(n) in list(node_crosswalk.keys()):
                    if n > 0:
                        node = map_new_id(n, node_crosswalk)
                    else:
                        node = -(map_new_id(abs(n), node_crosswalk))
                else:
                    print("Warning: old node id {} does not have correspondence".format(abs(n)))
                _existing.append(node)
            for n in p.get('set'):
                if abs(n) in list(node_crosswalk.keys()):
                    if n > 0:
                        node = map_new_id(n, node_crosswalk)
                    else:
                        node = -(map_new_id(abs(n), node_crosswalk))
                else:
                    print("Warning: old node id {} does not have correspondence".format(abs(n)))
                _set.append(node)
                
            p['existing'] = _existing
            p['set'] = _set

    return d

def roadway_id_change(d, links_missing_correspondence_list):
    """
    update model link and node id in roadway project cards
    """
    if d.get('category') in [
        'Roadway Property Change', 'Parallel Managed lanes'
    ]:
        
        if d.get('facility').get('link') == 'all':
            return d
        
        for link in d.get('facility').get('link'):
            if "model_link_id" in list(link.keys()):
                
                _model_link_id_list = []
                for l in link.get('model_link_id'):
                    if l in list(link_crosswalk.keys()):
                        #_model_link_id_list.append(
                        #    map_new_id(l, link_crosswalk)
                        #)
                        _model_link_id_list = _model_link_id_list + map_new_id(l, link_crosswalk)
                    else:
                        print("Warning: old link id {} does not have correspondence".format(abs(l)))
                        if l not in links_missing_correspondence_list:
                            links_missing_correspondence_list.append(l)

                link['model_link_id'] = _model_link_id_list
        
        return d
    
    if d.get('category') in ['Add New Roadway']:
        for link in d.get('links'):
            if link['A'] in list(node_crosswalk.keys()):
                link['A'] = map_new_id(link['A'], node_crosswalk)
            else:
                print("Warning: old node id {} does not have correspondence".format(abs(n)))
            if link['B'] in list(node_crosswalk.keys()):
                link['B'] = map_new_id(link['B'], node_crosswalk)
            else:
                print("Warning: old node id {} does not have correspondence".format(abs(n)))
        
        return d
    
    if d.get('category') in ['Roadway Deletion']:
        _model_link_id_list = []
        for l in d.get('links').get('model_link_id'):
            if l in list(link_crosswalk.keys()):
                link = map_new_id(l, link_crosswalk)

            else:
                print("Warning: old link id {} does not have correspondence".format(abs(l)))
                if l not in links_missing_correspondence_list:
                    links_missing_correspondence_list.append(l)
            #_model_link_id_list.append(link)
            _model_link_id_list = _model_link_id_list + link

        d['links']['model_link_id'] = _model_link_id_list
        
        return d
        

def update_id(card, links_missing_correspondence_list):
    """
    check if it's transit or highway project card
    """
    for change in card.changes:
        if change.get('category') == 'Transit Service Property Change':
            change = transit_id_change(change, links_missing_correspondence_list)

        else:
            change = roadway_id_change(change, links_missing_correspondence_list)

    return card, links_missing_correspondence_list

def update_project_cards(
    path,
):
    """
    main function
    """
    suffix = ["*.yaml", "*.yml"]
    card_list = []
    for s in suffix:
        card_list.extend(glob.glob(os.path.join(path, "**",s), recursive = True))
    print(str(len(card_list)) + " project cards")

    failed_df = pd.DataFrame()
        
    for file in card_list:
        card = ProjectCard.read(
            file,
            validate = False
        )

        links_missing_correspondence_list = []

        card, links_missing_correspondence_list = update_id(card, links_missing_correspondence_list)

        failed_df = pd.concat(
            [
                failed_df,
                pd.DataFrame(
                    data = {
                        "project_card_file_name": file, 
                        "old_model_id": links_missing_correspondence_list
                    }
                )
            ],
            sort = False,
            ignore_index = True
        )
        
        card.__dict__.pop('file', None)
        card.__dict__.pop('valid', None)
        
        card.write(
            filename = file
        )

    failed_df.drop_duplicates(inplace = True)
    
    return failed_df

# %%
# call main function
# All project cards currently refer to link ids only

links_failed_to_get_new_id_df = pd.DataFrame()

links_failed_to_get_new_id_df = update_project_cards(path = card_dir)
# Out:
# 101 project cards
# 2023-05-31 15:29:36, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp1.yml
# 2023-05-31 15:29:36, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp1.yml
# 2023-05-31 15:29:38, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp15.yml
# 2023-05-31 15:29:38, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp15.yml
# 2023-05-31 15:29:39, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp2.yml
# 2023-05-31 15:29:39, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp2.yml
# 2023-05-31 15:29:41, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp4.yml
# 2023-05-31 15:29:41, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp4.yml
# 2023-05-31 15:29:41, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp50.yml
# 2023-05-31 15:29:41, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp50.yml
# 2023-05-31 15:29:42, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp6.yml
# 2023-05-31 15:29:42, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp6.yml
# 2023-05-31 15:29:42, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp7.yml
# 2023-05-31 15:29:42, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\AsgnGrp7.yml
# Warning: old link id 9826 does not have correspondence
# Warning: old link id 9827 does not have correspondence
# 2023-05-31 15:29:46, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1A.yml
# 2023-05-31 15:29:46, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1A.yml
# 2023-05-31 15:29:50, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1B.yml
# 2023-05-31 15:29:50, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1B.yml
# Warning: old link id 210548 does not have correspondence
# 2023-05-31 15:29:56, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1C.yml
# 2023-05-31 15:29:56, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1C.yml
# 2023-05-31 15:30:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1D.yml
# 2023-05-31 15:30:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1D.yml
# Warning: old link id 383720 does not have correspondence
# Warning: old link id 393631 does not have correspondence
# 2023-05-31 15:30:09, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1E.yml
# 2023-05-31 15:30:09, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1E.yml
# 2023-05-31 15:30:15, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1F.yml
# 2023-05-31 15:30:15, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1F.yml
# 2023-05-31 15:30:22, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1G.yml
# 2023-05-31 15:30:22, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1G.yml
# 2023-05-31 15:30:25, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1H.yml
# 2023-05-31 15:30:25, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes1H.yml
# 2023-05-31 15:30:27, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2A.yml
# 2023-05-31 15:30:27, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2A.yml
# 2023-05-31 15:30:30, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2B.yml
# 2023-05-31 15:30:30, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2B.yml
# 2023-05-31 15:30:36, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2C.yml
# 2023-05-31 15:30:36, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2C.yml
# Warning: old link id 392913 does not have correspondence
# Warning: old link id 393984 does not have correspondence
# Warning: old link id 394398 does not have correspondence
# Warning: old link id 395912 does not have correspondence
# Warning: old link id 395921 does not have correspondence
# 2023-05-31 15:30:43, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2D.yml
# 2023-05-31 15:30:43, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2D.yml
# Warning: old link id 413559 does not have correspondence
# 2023-05-31 15:30:48, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2E.yml
# 2023-05-31 15:30:48, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes2E.yml
# 2023-05-31 15:30:54, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes3.yml
# 2023-05-31 15:30:54, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes3.yml
# 2023-05-31 15:30:55, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes4.yml
# 2023-05-31 15:30:55, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes4.yml
# 2023-05-31 15:30:56, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lanes5.yml
# 2023-05-31 15:30:56, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\BaseCorrections\Lan
yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-494ExpansionI-94toTamarackRd.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-494ExpansionI-94toTamarackRd.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-694ExpansionI-694to10thSt.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-694ExpansionI-694to10thSt.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-94ExpansionDaytonPkwytoMN101.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-94ExpansionDaytonPkwytoMN101.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-94ExpansionMN610toBrocktonAve.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-94ExpansionMN610toBrocktonAve.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-94ExpansionTH41toCR19.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\I-94ExpansionTH41toCR19.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN101Expansion.yml
# 2023-05-31 15:31:58, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN101Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN41RoadDiet.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN41RoadDiet.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN51Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN51Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN5Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN5Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN97ExpansionatI-35.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\MN97ExpansionatI-35.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\ScottCR27Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\ScottCR27Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\ScottCR42Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\ScottCR42Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR13Expansion.yml
# 2023-05-31 15:31:59, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR13Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR15Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR15Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR18Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR18Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR19Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WashingtonCR19Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WrightCountyCSAH19Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WrightCountyCSAH19Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WrightCR19Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_2040\WrightCR19Expansion.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\252_94_NB_MnPASS.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\252_94_NB_MnPASS.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\252_94_SB_MnPASS.yml
# 2023-05-31 15:32:00, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\252_94_SB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\35W_RamseyC-Downtown_SB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\35W_RamseyC-Downtown_SB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\494_France-MN77_EB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\494_France-MN77_EB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\494_MN77-35W_WB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\494_MN77-35W_WB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\94_Minneapolis-Saint_Paul_EB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\94_Minneapolis-Saint_Paul_EB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\94_Minneapolis-Saint_Paul_WB_MnPASS.yml
# 2023-05-31 15:32:01, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\CRS_MnPASS\94_Minneapolis-Saint_Paul_WB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-494_NB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-494_NB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-494_SB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-494_SB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-694_NB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-694_NB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-694_SB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_394-694_SB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_ScottCR17-494_NB_MnPASS.yml
# 2023-05-31 15:32:02, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_ScottCR17-494_NB_MnPASS.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_ScottCR17-494_SB_MnPASS.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\169_ScottCR17-494_SB_MnPASS.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\252_94_NB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\252_94_NB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\252_94_SB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\252_94_SB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35E_NB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35E_NB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35E_SB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35E_SB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35W_RamseyC-Downtown_NB_MnPASS.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35W_RamseyC-Downtown_NB_MnPASS.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35_NB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35_NB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35_SB_MnPASS_Extension.yml
# 2023-05-31 15:32:03, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\35_SB_MnPASS_Extension.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\494_West_Bush-MN5_EB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\494_West_Bush-MN5_EB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\494_West_Bush-MN5_WB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\494_West_Bush-MN5_WB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN101_EB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN101_EB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN101_WB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN101_WB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN252_EB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN252_EB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN252_WB_MnPASS.yml
# 2023-05-31 15:32:04, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\94_494-MN252_WB_MnPASS.yml
# 2023-05-31 15:32:05, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\MN36_EB_MnPASS.yml
# 2023-05-31 15:32:05, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\MN36_EB_MnPASS.yml
# 2023-05-31 15:32:05, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\MN36_WB_MnPASS.yml
# 2023-05-31 15:32:05, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\MN36_WB_MnPASS.yml
# 2023-05-31 15:32:05, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\MN77_NB_MnPASS.yml
# 2023-05-31 15:32:05, INFO: Wrote project card to: D:/metcouncil_network_rebuild\ProjectCards_new_network\IRS_2040\MnPASS\MN77_NB_MnPASS.yml

# %%
links_failed_to_get_new_id_df['old_model_id'] = links_failed_to_get_new_id_df['old_model_id'].astype(int)

# %%
# write out old links ids in project cards that did not have a new link id correspondence
# use might need to manually check and add those correspondence

links_failed_to_get_new_id_df.to_csv(os.path.join(card_dir, "missing_links_in_new_cards.csv"), sep=',',index=False)
